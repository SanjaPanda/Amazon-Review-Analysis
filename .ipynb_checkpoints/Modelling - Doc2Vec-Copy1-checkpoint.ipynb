# %%
import pandas as pd
import string
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

import pattern
from pattern.en import lemma

from gensim.models import Word2Vec

import numpy as np
import re

from sklearn.model_selection import KFold, cross_val_score, train_test_split
import matplotlib.pyplot as plt

# %%
review_df = pd.read_csv('Review_Data.csv')
stop_words = set(stopwords.words('english'))

# %%
review_df.head()
# Out:
#          asin                                              title  \
# 0  B0855T8JT2  \n\n\n\n\n\n\n\n  \n  \n    Poor call quality ...
# 1  B0855T8JT2     \n\n\n\n\n\n\n\n  \n  \n    Sound Output\n  \n
# 2  B0855T8JT2        \n\n\n\n\n\n\n\n  \n  \n    Wonderful\n  \n
# 3  B0855T8JT2               \n\n\n\n\n\n\n\n  \n  \n    Hi\n  \n
# 4  B0855T8JT2  \n\n\n\n\n\n\n\n  \n  \n    Best earbuds for 5...
#
#                                               review  star
# 0  \n\n\n\n\n\n\n\n\n\n  \n  \n    \n  Got these ...   3.0
# 1  \n\n\n\n\n\n\n\n\n\n  \n  \n    \n  Music qual...   5.0
# 2  \n\n\n\n\n\n\n\n\n\n  \n  \n    \n  I was a bi...   5.0
# 3     \n\n\n\n\n\n\n\n\n\n  \n  \n    \n  Hi\n\n  \n   4.0
# 4  \n\n\n\n\n\n\n\n\n\n  \n  \n    \n  The produc...   5.0

# %%
cols = ['title', 'review']
review_df['combined'] = review_df[cols].apply(lambda row: '\n'.join(row.values.astype(str)), axis=1)
review_df.drop(['title','review'],axis = 1,inplace = True)
review_df.head()
# Out:
#          asin  star                                           combined
# 0  B0855T8JT2   3.0  \n\n\n\n\n\n\n\n  \n  \n    Poor call quality ...
# 1  B0855T8JT2   5.0  \n\n\n\n\n\n\n\n  \n  \n    Sound Output\n  \n...
# 2  B0855T8JT2   5.0  \n\n\n\n\n\n\n\n  \n  \n    Wonderful\n  \n\n\...
# 3  B0855T8JT2   4.0  \n\n\n\n\n\n\n\n  \n  \n    Hi\n  \n\n\n\n\n\n...
# 4  B0855T8JT2   5.0  \n\n\n\n\n\n\n\n  \n  \n    Best earbuds for 5...

# %%
def clean_data(stri):
    sent_lst = []

    for sent in sent_tokenize(stri):
        lst = []
        for word in word_tokenize(sent):
            if(word.isalpha() and not word in stop_words and len(word)>1):
                lst.append(word.lower())
        #clean_sent = ' '.join(lst)
        #sent_lst.append(clean_sent)
        sent_lst = sent_lst+lst

    para = '. '.join(sent_lst)
    return sent_lst

# %%
review_df['combined'] = review_df['combined'].apply(lambda x: clean_data(x))

# %%
review_df.head()
# Out:
#          asin  star                                           combined
# 0  B0855T8JT2   3.0  [poor, call, quality, return, got, earphones, ...
# 1  B0855T8JT2   5.0  [sound, output, music, quality, way, better, c...
# 2  B0855T8JT2   5.0  [wonderful, bit, skeptical, buying, performing...
# 3  B0855T8JT2   4.0                                           [hi, hi]
# 4  B0855T8JT2   5.0  [best, earbuds, rs, the, product, feels, premi...

# %%
review_df['combined'][0]
# Out:
# ['poor',
#  'call',
#  'quality',
#  'return',
#  'got',
#  'earphones',
#  'long',
#  'research',
#  'the',
#  'online',
#  'reviews',
#  'focus',
#  'mostly',
#  'sound',
#  'quality',
#  'these',
#  'buds',
#  'perform',
#  'well',
#  'department',
#  'dual',
#  'drivers',
#  'deliver',
#  'good',
#  'loud',
#  'output',
#  'the',
#  'case',
#  'made',
#  'soft',
#  'touch',
#  'plastic',
#  'the',
#  'magnetic',
#  'buds',
#  'snap',
#  'perfectly',
#  'no',
#  'complaints',
#  'design',
#  'build',
#  'fail',
#  'miserably',
#  'microphone',
#  'department',
#  'write',
#  'review',
#  'others',
#  'buy',
#  'point',
#  'mind',
#  'could',
#  'find',
#  'detailed',
#  'review',
#  'call',
#  'quality',
#  'suffer',
#  'calls',
#  'sound',
#  'muffled',
#  'mics',
#  'the',
#  'person',
#  'end',
#  'always',
#  'complaints',
#  'regarding',
#  'sound',
#  'quiet',
#  'noisy',
#  'environment',
#  'sounding',
#  'really',
#  'bad',
#  'personally',
#  'heard',
#  'pairing',
#  'someone',
#  'else',
#  'phone',
#  'microphones',
#  'truly',
#  'would',
#  'like',
#  'comment',
#  'fit',
#  'okay',
#  'provide',
#  'much',
#  'passive',
#  'noise',
#  'deal',
#  'free',
#  'movie',
#  'vouches',
#  'posting',
#  'review',
#  'amazon',
#  'are',
#  'kidding',
#  'crossbeats',
#  'have',
#  'returned',
#  'product']

# %%
review_df['star'].value_counts()
# Out:
# 5.0    1082
# 1.0     706
# 4.0     444
# 3.0     289
# 2.0     234
# Name: star, dtype: int64

# %%
def update_star(star):
    if star == 5:
        return 1
    elif star in [3,4]:
        return 0
    else:
        return -1

review_df['star'] = review_df['star'].apply(lambda x: update_star(x))

review_df['star'].value_counts()
# Out:
#  1    1082
# -1     940
#  0     733
# Name: star, dtype: int64

# %%
#Import packages
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

## Exapmple document (list of sentences)
doc = list(review_df['combined'].values)

# Tokenization of each document
tokenized_doc = []
for d in doc:
    for i in d:
        tokenized_doc.append(word_tokenize(i.lower()))
tokenized_doc
# Out:
# [['poor'],
#  ['call'],
#  ['quality'],
#  ['return'],
#  ['got'],
#  ['earphones'],
#  ['long'],
#  ['research'],
#  ['the'],
#  ['online'],
#  ['reviews'],
#  ['focus'],
#  ['mostly'],
#  ['sound'],
#  ['quality'],
#  ['these'],
#  ['buds'],
#  ['perform'],
#  ['well'],
#  ['department'],
#  ['dual'],
#  ['drivers'],
#  ['deliver'],
#  ['good'],
#  ['loud'],
#  ['output'],
#  ['the'],
#  ['case'],
#  ['made'],
#  ['soft'],
#  ['touch'],
#  ['plastic'],
#  ['the'],
#  ['magnetic'],
#  ['buds'],
#  ['snap'],
#  ['perfectly'],
#  ['no'],
#  ['complaints'],
#  ['design'],
#  ['build'],
#  ['fail'],
#  ['miserably'],
#  ['microphone'],
#  ['department'],
#  ['write'],
#  ['review'],
#  ['others'],
#  ['buy'],
#  ['point'],
#  ['mind'],
#  ['could'],
#  ['find'],
#  ['detailed'],
#  ['review'],
#  ['call'],
#  ['quality'],
#  ['suffer'],
#  ['calls'],
#  ['sound'],
#  ['muffled'],
#  ['mics'],
#  ['the'],
#  ['person'],
#  ['end'],
#  ['always'],
#  ['complaints'],
#  ['regarding'],
#  ['sound'],
#  ['quiet'],
#  ['noisy'],
#  ['environment'],
#  ['sounding'],
#  ['really'],
#  ['bad'],
#  ['personally'],
#  ['heard'],
#  ['pairing'],
#  ['someone'],
#  ['else'],
#  ['phone'],
#  ['microphones'],
#  ['truly'],
#  ['would'],
#  ['like'],
#  ['comment'],
#  ['fit'],
#  ['okay'],
#  ['provide'],
#  ['much'],
#  ['passive'],
#  ['noise'],
#  ['deal'],
#  ['free'],
#  ['movie'],
#  ['vouches'],
#  ['posting'],
#  ['review'],
#  ['amazon'],
#  ['are'],
#  ['kidding'],
#  ['crossbeats'],
#  ['have'],
#  ['returned'],
#  ['product'],
#  ['sound'],
#  ['output'],
#  ['music'],
#  ['quality'],
#  ['way'],
#  ['better'],
#  ['competitors'],
#  ['quality'],
#  ['decent'],
#  ['enough'],
#  ['could'],
#  ['better'],
#  ['mic'],
#  ['sometimes'],
#  ['sounds'],
#  ['muffled'],
#  ['cancellation'],
#  ['way'],
#  ['good'],
#  ['case'],
#  ['premium'],
#  ['green'],
#  ['far'],
#  ['better'],
#  ['earpods'],
#  ['light'],
#  ['snug'],
#  ['fit'],
#  ['easily'],
#  ['go'],
#  ['gym'],
#  ['wearing'],
#  ['exercise'],
#  ['whic'],
#  ['includes'],
#  ['running'],
#  ['dont'],
#  ['fall'],
#  ['wonderful'],
#  ['bit'],
#  ['skeptical'],
#  ['buying'],
#  ['performing'],
#  ['beyond'],
#  ['expectations'],
#  ['sleek'],
#  ['design'],
#  ['high'],
#  ['quality'],
#  ['audio'],
#  ['will'],
#  ['update'],
#  ['week'],
#  ['use'],
#  ['hi'],
#  ['hi'],
#  ['best'],
#  ['earbuds'],
#  ['rs'],
#  ['the'],
#  ['product'],
#  ['feels'],
#  ['premium'],
#  ['fit'],
#  ['earbuds'],
#  ['soo'],
#  ['like'],
#  ['wearing'],
#  ['it'],
#  ['light'],
#  ['sounds'],
#  ['good'],
#  ['bass'],
#  ['punchy'],
#  ['sound'],
#  ['stage'],
#  ['also'],
#  ['good'],
#  ['compared'],
#  ['must'],
#  ['buy'],
#  ['ur'],
#  ['budget'],
#  ['around'],
#  ['do'],
#  ['buy'],
#  ['waste'],
#  ['money'],
#  ['pathetic'],
#  ['earpods'],
#  ['one'],
#  ['side'],
#  ['worked'],
#  ['head'],
#  ['tilted'],
#  ['towards'],
#  ['one'],
#  ['side'],
#  ['as'],
#  ['soon'],
#  ['keep'],
#  ['head'],
#  ['straight'],
#  ['right'],
#  ['side'],
#  ['stops'],
#  ['working'],
#  ['it'],
#  ['frustrating'],
#  ['utter'],
#  ['waste'],
#  ['time'],
#  ['returned'],
#  ['worth'],
#  ['amount'],
#  ['if'],
#  ['selling'],
#  ['someone'],
#  ['item'],
#  ['worth'],
#  ['least'],
#  ['proper'],
#  ['quality'],
#  ['check'],
#  ['good'],
#  ['sound'],
#  ['quality'],
#  ['good'],
#  ['not'],
#  ['value'],
#  ['money'],
#  ['looks'],
#  ['sounds'],
#  ['like'],
#  ['cheap'],
#  ['china'],
#  ['product'],
#  ['cranky'],
#  ['sound'],
#  ['press'],
#  ['buttons'],
#  ['next'],
#  ['track'],
#  ['also'],
#  ['fits'],
#  ['comfortable'],
#  ['ears'],
#  ['also'],
#  ['earbuds'],
#  ['rubber'],
#  ['quality'],
#  ['poor'],
#  ['pretty'],
#  ['bad'],
#  ['performance'],
#  ['bass'],
#  ['treble'],
#  ['hurts'],
#  ['ears'],
#  ['ordinary'],
#  ['sound'],
#  ['ordinary'],
#  ['bass'],
#  ['ordinary'],
#  ['fit'],
#  ['everything'],
#  ['ordinary'],
#  ['earphones'],
#  ['purchased'],
#  ['reading'],
#  ['good'],
#  ['reviews'],
#  ['using'],
#  ['around'],
#  ['min'],
#  ['wondered'],
#  ['wrong'],
#  ['people'],
#  ['giving'],
#  ['good'],
#  ['reviews'],
#  ['definitely'],
#  ['trust'],
#  ['bad'],
#  ['reviews'],
#  ['expect'],
#  ['better'],
#  ['performance'],
#  ['buying'],
#  ['earphones'],
#  ['audio'],
#  ['voice'],
#  ['yet'],
#  ['another'],
#  ['ear'],
#  ['piece'],
#  ['awesome'],
#  ['audio'],
#  ['scores'],
#  ['zero'],
#  ['call'],
#  ['quality'],
#  ['not'],
#  ['calls'],
#  ['workout'],
#  ['workout'],
#  ['no'],
#  ['falls'],
#  ['tried'],
#  ['pairs'],
#  ['one'],
#  ['star'],
#  ['market'],
#  ['perfect'],
#  ['working'],
#  ['even'],
#  ['extreme'],
#  ['quiet'],
#  ['person'],
#  ['struggle'],
#  ['hear'],
#  ['the'],
#  ['mic'],
#  ['big'],
#  ['sticks'],
#  ['ear'],
#  ['does'],
#  ['fit'],
#  ['like'],
#  ['shown'],
#  ['pictures'],
#  ['it'],
#  ['clearly'],
#  ['visible'],
#  ['almost'],
#  ['looks'],
#  ['like'],
#  ['idea'],
#  ['listento'],
#  ['music'],
#  ['sound'],
#  ['crisp'],
#  ['bass'],
#  ['bluetooth'],
#  ['auto'],
#  ['connects'],
#  ['one'],
#  ['earphone'],
#  ['value'],
#  ['money'],
#  ['wait'],
#  ['better'],
#  ['options'],
#  ['buy'],
#  ['brands'],
#  ['passed'],
#  ['deadline'],
#  ['return'],
#  ['product'],
#  ['stuck'],
#  ['use'],
#  ['listen'],
#  ['music'],
#  ['alright'],
#  ['okay'],
#  ['price'],
#  ['point'],
#  ['if'],
#  ['finicky'],
#  ['audio'],
#  ['quality'],
#  ['pros'],
#  ['the'],
#  ['design'],
#  ['case'],
#  ['headphones'],
#  ['amazing'],
#  ['looks'],
#  ['sleek'],
#  ['build'],
#  ['light'],
#  ['weight'],
#  ['barely'],
#  ['feel'],
#  ['the'],
#  ['button'],
#  ['controls'],
#  ['pretty'],
#  ['battery'],
#  ['life'],
#  ['adequate'],
#  ['average'],
#  ['userscons'],
#  ['audio'],
#  ['quality'],
#  ['quite'],
#  ['average'],
#  ['specially'],
#  ['compared'],
#  ['products'],
#  ['crossbeats'],
#  ['there'],
#  ['noise'],
#  ['cancellation'],
#  ['overall'],
#  ['sound'],
#  ['quality'],
#  ['calls'],
#  ['badit'],
#  ['still'],
#  ['decent'],
#  ['product'],
#  ['sound'],
#  ['quality'],
#  ['think'],
#  ['overpriced'],
#  ['bang'],
#  ['buck'],
#  ['wireless'],
#  ['marvel'],
#  ['when'],
#  ['people'],
#  ['praised'],
#  ['look'],
#  ['earphones'],
#  ['sky'],
#  ['though'],
#  ['kidding'],
#  ['these'],
#  ['really'],
#  ['adorable'],
#  ['ear'],
#  ['pieces'],
#  ['pair'],
#  ['amazingly'],
#  ['quickly'],
#  ['tab'],
#  ['phone'],
#  ['using'],
#  ['bt'],
#  ['the'],
#  ['sound'],
#  ['quality'],
#  ['stunning'],
#  ['right'],
#  ['levels'],
#  ['bass'],
#  ['treble'],
#  ['however'],
#  ['sometimes'],
#  ['calls'],
#  ['need'],
#  ['hold'],
#  ['one'],
#  ['ear'],
#  ['piece'],
#  ['near'],
#  ['mouth'],
#  ['loud'],
#  ['enough'],
#  ['dual'],
#  ['mics'],
#  ['ear'],
#  ['pieces'],
#  ['pick'],
#  ['voice'],
#  ['so'],
#  ['low'],
#  ['tone'],
#  ['mushy'],
#  ['calls'],
#  ['hehe'],
#  ['low'],
#  ['latency'],
#  ['means'],
#  ['video'],
#  ['viewing'],
#  ['without'],
#  ['audio'],
#  ['lag'],
#  ['love'],
#  ['charge'],
#  ['cute'],
#  ['little'],
#  ['case'],
#  ['every'],
#  ['time'],
#  ['put'],
#  ['ready'],
#  ['next'],
#  ['listen'],
#  ['the'],
#  ['case'],
#  ['easily'],
#  ['fit'],
#  ['pocket'],
#  ['quite'],
#  ['sturdy'],
#  ['super'],
#  ['portable'],
#  ['you'],
#  ['never'],
#  ['run'],
#  ['offer'],
#  ['grreat'],
#  ['value'],
#  ['money'],
#  ['the'],
#  ['case'],
#  ['also'],
#  ['type'],
#  ['fast'],
#  ['charging'],
#  ['unit'],
#  ['yet'],
#  ['try'],
#  ['use'],
#  ['charger'],
#  ['power'],
#  ['bank'],
#  ['do'],
#  ['fall'],
#  ['paid'],
#  ['positive'],
#  ['reviews'],
#  ['first'],
#  ['would'],
#  ['like'],
#  ['warn'],
#  ['positive'],
#  ['reviews'],
#  ['paid'],
#  ['reviews'],
#  ['incentive'],
#  ['months'],
#  ['ganna'],
#  ['subscription'],
#  ['as'],
#  ['soon'],
#  ['register'],
#  ['product'],
#  ['warranty'],
#  ['start'],
#  ['getting'],
#  ['whatsapp'],
#  ['messages'],
#  ['calls'],
#  ['crossbeats'],
#  ['customer'],
#  ['representative'],
#  ['number'],
#  ['continuously'],
#  ['asking'],
#  ['send'],
#  ['screenshot'],
#  ['positive'],
#  ['review'],
#  ['exchange'],
#  ['months'],
#  ['gaana'],
#  ['subscription'],
#  ['they'],
#  ['dedicated'],
#  ['channel'],
#  ['pushing'],
#  ['customers'],
#  ['give'],
#  ['positive'],
#  ['reviews'],
#  ['case'],
#  ['face'],
#  ['issue'],
#  ['way'],
#  ['directly'],
#  ['talk'],
#  ['customer'],
#  ['representative'],
#  ['resolve'],
#  ['you'],
#  ['send'],
#  ['mail'],
#  ['support'],
#  ['wait'],
#  ['hours'],
#  ['reply'],
#  ['first'],
#  ['mail'],
#  ['reply'],
#  ['ask'],
#  ['invoice'],
#  ['product'],
#  ['details'],
#  ['even'],
#  ['though'],
#  ['sending'],
#  ['mail'],
#  ['mail'],
#  ['id'],
#  ['product'],
#  ['registered'],
#  ['in'],
#  ['second'],
#  ['mail'],
#  ['ask'],
#  ['restart'],
#  ['bud'],
#  ['check'],
#  ['resolves'],
#  ['issue'],
#  ['third'],
#  ['mail'],
#  ['ask'],
#  ['record'],
#  ['video'],
#  ['problem'],
#  ['send'],
#  ['facing'],
#  ['audio'],
#  ['connectivity'],
#  ['issue'],
#  ['still'],
#  ['asked'],
#  ['send'],
#  ['video'],
#  ['know'],
#  ['record'],
#  ['video'],
#  ['so'],
#  ['average'],
#  ['almost'],
#  ['week'],
#  ['till'],
#  ['get'],
#  ['actual'],
#  ['response'],
#  ['problem'],
#  ['now'],
#  ['whether'],
#  ['actually'],
#  ['help'],
#  ['another'],
#  ['connectivity'],
#  ['issue'],
#  ['audio'],
#  ['output'],
#  ['right'],
#  ['bud'],
#  ['getting'],
#  ['disrupted'],
#  ['frequently'],
#  ['it'],
#  ['split'],
#  ['second'],
#  ['every'],
#  ['seconds'],
#  ['repeating'],
#  ['like'],
#  ['irritating'],
#  ['and'],
#  ['response'],
#  ['finally'],
#  ['got'],
#  ['one'],
#  ['week'],
#  ['this'],
#  ['standard'],
#  ['across'],
#  ['bluetooth'],
#  ['powered'],
#  ['devices'],
#  ['told'],
#  ['wifi'],
#  ['bluetooth'],
#  ['connection'],
#  ['getting'],
#  ['disrupted'],
#  ['normal'],
#  ['but'],
#  ['replied'],
#  ['using'],
#  ['bluetooth'],
#  ['earphone'],
#  ['bluetooth'],
#  ['speaker'],
#  ['brands'],
#  ['years'],
#  ['never'],
#  ['faced'],
#  ['issue'],
#  ['surely'],
#  ['standard'],
#  ['bluetooth'],
#  ['devices'],
#  ['even'],
#  ['left'],
#  ['bud'],
#  ['working'],
#  ['fine'],
#  ['right'],
#  ['one'],
#  ['problem'],
#  ['got'],
#  ['reply'],
#  ['since'],
#  ['bought'],
#  ['less'],
#  ['month'],
#  ['ago'],
#  ['asked'],
#  ['replacement'],
#  ['could'],
#  ['help'],
#  ['fix'],
#  ['issue'],
#  ['got'],
#  ['response'],
#  ['since'],
#  ['but'],
#  ['getting'],
#  ['positive'],
#  ['review'],
#  ['send'],
#  ['whatsapp'],
#  ['reminder'],
#  ['everyday'],
#  ['call'],
#  ['every'],
#  ['alternate'],
#  ['day'],
#  ['without'],
#  ['fail'],
#  ['rip'],
#  ['it'],
#  ['rip'],
#  ['offits'],
#  ['jus'],
#  ['good'],
#  ['looking'],
#  ['headphone'],
#  ['functionality'],
#  ['problemsi'],
#  ['regret'],
#  ['going'],
#  ['itnoise'],
#  ['cancellation'],
#  ['crappy'],
#  ['andvoice'],
#  ['echo'],
#  ['sorts'],
#  ['callsand'],
#  ['support'],
#  ['customer'],
#  ['care'],
#  ['the'],
#  ['design'],
#  ['look'],
#  ['earphones'],
#  ['amazing'],
#  ['it'],
#  ['got'],
#  ['good'],
#  ['battery'],
#  ['life'],
#  ['handy'],
#  ['device'],
#  ['decent'],
#  ['sound'],
#  ['slick'],
#  ['design'],
#  ['connection'],
#  ['reset'],
#  ['guide'],
#  ['given'],
#  ['the'],
#  ['microphone'],
#  ['horrible'],
#  ['constant'],
#  ['noise'],
#  ['receiving'],
#  ['end'],
#  ['hard'],
#  ['time'],
#  ['connecting'],
#  ['device'],
#  ['fails'],
#  ['detect'],
#  ['individual'],
#  ['price'],
#  ['high'],
#  ['compare'],
#  ['basic'],
#  ['services'],
#  ['bass'],
#  ['one'],
#  ['would'],
#  ['expect'],
#  ['hint'],
#  ['bass'],
#  ['needs'],
#  ['high'],
#  ['great'],
#  ['audio'],
#  ['quality'],
#  ['battery'],
#  ['life'],
#  ['looks'],
#  ['price'],
#  ['range'],
#  ['for'],
#  ['details'],
#  ['read'],
#  ['pros'],
#  ['product'],
#  ['made'],
#  ['india'],
#  ['indian'],
#  ['origin'],
#  ['startup'],
#  ['looks'],
#  ['awesome'],
#  ['looking'],
#  ['earbuds'],
#  ['sleek'],
#  ['chic'],
#  ['charging'],
#  ['case'],
#  ['good'],
#  ['battery'],
#  ['fast'],
#  ['charging'],
#  ['charging'],
#  ['big'],
#  ['plus'],
#  ['point'],
#  ['very'],
#  ['good'],
#  ['audio'],
#  ['quality'],
#  ['especially'],
#  ['very'],
#  ['good'],
#  ['very'],
#  ['good'],
#  ['audio'],
#  ['person'],
#  ['calling'],
#  ['bad'],
#  ['audio'],
#  ['us'],
#  ['person'],
#  ['button'],
#  ['makes'],
#  ['kinda'],
#  ['loud'],
#  ['sound'],
#  ['pressed'],
#  ['earbuds'],
#  ['earverdict'],
#  ['great'],
#  ['audio'],
#  ['quality'],
#  ['great'],
#  ['battery'],
#  ['life'],
#  ['great'],
#  ['looks'],
#  ['price'],
#  ['range'],
#  ['got'],
#  ['cheated'],
#  ['fake'],
#  ['youtubers'],
#  ['heard'],
#  ['great'],
#  ['reviews'],
#  ['product'],
#  ['youtubers'],
#  ['like'],
#  ['technology'],
#  ['jock'],
#  ['others'],
#  ['quite'],
#  ['interested'],
#  ['listening'],
#  ['highly'],
#  ['positive'],
#  ['views'],
#  ['product'],
#  ['later'],
#  ['receiving'],
#  ['understood'],
#  ['paid'],
#  ['promote'],
#  ['the'],
#  ['audio'],
#  ['quality'],
#  ['pathetic'],
#  ['like'],
#  ['cheap'],
#  ['chinese'],
#  ['wired'],
#  ['earphones'],
#  ['after'],
#  ['even'],
#  ['chinese'],
#  ['product'],
#  ['am'],
#  ['meaning'],
#  ['sound'],
#  ['biased'],
#  ['infact'],
#  ['using'],
#  ['chinese'],
#  ['products'],
#  ['garbage'],
#  ['not'],
#  ['worth'],
#  ['price'],
#  ['even'],
#  ['worth'],
#  ['the'],
#  ['quality'],
#  ['earbuds'],
#  ['plasticy'],
#  ['feels'],
#  ['delicate'],
#  ['even'],
#  ['fit'],
#  ['ear'],
#  ['properly'],
#  ['dont'],
#  ['buy'],
#  ['save'],
#  ['money'],
#  ['go'],
#  ['another'],
#  ['product'],
#  ['nice'],
#  ['product'],
#  ['this'],
#  ['first'],
#  ['tws'],
#  ['bluetooth'],
#  ['earbuds'],
#  ['lot'],
#  ['research'],
#  ['bought'],
#  ['connectivity'],
#  ['swift'],
#  ['moment'],
#  ['taken'],
#  ['case'],
#  ['get'],
#  ['connected'],
#  ['connected'],
#  ['built'],
#  ['quality'],
#  ['nice'],
#  ['soft'],
#  ['feel'],
#  ['good'],
#  ['material'],
#  ['quality'],
#  ['elegant'],
#  ['colour'],
#  ['combo'],
#  ['imperial'],
#  ['jade'],
#  ['less'],
#  ['weight'],
#  ['good'],
#  ['fit'],
#  ['ears'],
#  ['used'],
#  ['still'],
#  ['good'],
#  ['charge'],
#  ['connectivity'],
#  ['about'],
#  ['charge'],
#  ['review'],
#  ['week'],
#  ['while'],
#  ['connecting'],
#  ['mono'],
#  ['two'],
#  ['earbuds'],
#  ['connected'],
#  ['mobile'],
#  ['devices'],
#  ['like'],
#  ['bud'],
#  ['one'],
#  ['mobile'],
#  ['bud'],
#  ...]

# %%
# Convert tokenized document into gensim formated tagged data
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(tokenized_doc)]
tagged_data
# Out:
# [TaggedDocument(words=['poor'], tags=[0]),
#  TaggedDocument(words=['call'], tags=[1]),
#  TaggedDocument(words=['quality'], tags=[2]),
#  TaggedDocument(words=['return'], tags=[3]),
#  TaggedDocument(words=['got'], tags=[4]),
#  TaggedDocument(words=['earphones'], tags=[5]),
#  TaggedDocument(words=['long'], tags=[6]),
#  TaggedDocument(words=['research'], tags=[7]),
#  TaggedDocument(words=['the'], tags=[8]),
#  TaggedDocument(words=['online'], tags=[9]),
#  TaggedDocument(words=['reviews'], tags=[10]),
#  TaggedDocument(words=['focus'], tags=[11]),
#  TaggedDocument(words=['mostly'], tags=[12]),
#  TaggedDocument(words=['sound'], tags=[13]),
#  TaggedDocument(words=['quality'], tags=[14]),
#  TaggedDocument(words=['these'], tags=[15]),
#  TaggedDocument(words=['buds'], tags=[16]),
#  TaggedDocument(words=['perform'], tags=[17]),
#  TaggedDocument(words=['well'], tags=[18]),
#  TaggedDocument(words=['department'], tags=[19]),
#  TaggedDocument(words=['dual'], tags=[20]),
#  TaggedDocument(words=['drivers'], tags=[21]),
#  TaggedDocument(words=['deliver'], tags=[22]),
#  TaggedDocument(words=['good'], tags=[23]),
#  TaggedDocument(words=['loud'], tags=[24]),
#  TaggedDocument(words=['output'], tags=[25]),
#  TaggedDocument(words=['the'], tags=[26]),
#  TaggedDocument(words=['case'], tags=[27]),
#  TaggedDocument(words=['made'], tags=[28]),
#  TaggedDocument(words=['soft'], tags=[29]),
#  TaggedDocument(words=['touch'], tags=[30]),
#  TaggedDocument(words=['plastic'], tags=[31]),
#  TaggedDocument(words=['the'], tags=[32]),
#  TaggedDocument(words=['magnetic'], tags=[33]),
#  TaggedDocument(words=['buds'], tags=[34]),
#  TaggedDocument(words=['snap'], tags=[35]),
#  TaggedDocument(words=['perfectly'], tags=[36]),
#  TaggedDocument(words=['no'], tags=[37]),
#  TaggedDocument(words=['complaints'], tags=[38]),
#  TaggedDocument(words=['design'], tags=[39]),
#  TaggedDocument(words=['build'], tags=[40]),
#  TaggedDocument(words=['fail'], tags=[41]),
#  TaggedDocument(words=['miserably'], tags=[42]),
#  TaggedDocument(words=['microphone'], tags=[43]),
#  TaggedDocument(words=['department'], tags=[44]),
#  TaggedDocument(words=['write'], tags=[45]),
#  TaggedDocument(words=['review'], tags=[46]),
#  TaggedDocument(words=['others'], tags=[47]),
#  TaggedDocument(words=['buy'], tags=[48]),
#  TaggedDocument(words=['point'], tags=[49]),
#  TaggedDocument(words=['mind'], tags=[50]),
#  TaggedDocument(words=['could'], tags=[51]),
#  TaggedDocument(words=['find'], tags=[52]),
#  TaggedDocument(words=['detailed'], tags=[53]),
#  TaggedDocument(words=['review'], tags=[54]),
#  TaggedDocument(words=['call'], tags=[55]),
#  TaggedDocument(words=['quality'], tags=[56]),
#  TaggedDocument(words=['suffer'], tags=[57]),
#  TaggedDocument(words=['calls'], tags=[58]),
#  TaggedDocument(words=['sound'], tags=[59]),
#  TaggedDocument(words=['muffled'], tags=[60]),
#  TaggedDocument(words=['mics'], tags=[61]),
#  TaggedDocument(words=['the'], tags=[62]),
#  TaggedDocument(words=['person'], tags=[63]),
#  TaggedDocument(words=['end'], tags=[64]),
#  TaggedDocument(words=['always'], tags=[65]),
#  TaggedDocument(words=['complaints'], tags=[66]),
#  TaggedDocument(words=['regarding'], tags=[67]),
#  TaggedDocument(words=['sound'], tags=[68]),
#  TaggedDocument(words=['quiet'], tags=[69]),
#  TaggedDocument(words=['noisy'], tags=[70]),
#  TaggedDocument(words=['environment'], tags=[71]),
#  TaggedDocument(words=['sounding'], tags=[72]),
#  TaggedDocument(words=['really'], tags=[73]),
#  TaggedDocument(words=['bad'], tags=[74]),
#  TaggedDocument(words=['personally'], tags=[75]),
#  TaggedDocument(words=['heard'], tags=[76]),
#  TaggedDocument(words=['pairing'], tags=[77]),
#  TaggedDocument(words=['someone'], tags=[78]),
#  TaggedDocument(words=['else'], tags=[79]),
#  TaggedDocument(words=['phone'], tags=[80]),
#  TaggedDocument(words=['microphones'], tags=[81]),
#  TaggedDocument(words=['truly'], tags=[82]),
#  TaggedDocument(words=['would'], tags=[83]),
#  TaggedDocument(words=['like'], tags=[84]),
#  TaggedDocument(words=['comment'], tags=[85]),
#  TaggedDocument(words=['fit'], tags=[86]),
#  TaggedDocument(words=['okay'], tags=[87]),
#  TaggedDocument(words=['provide'], tags=[88]),
#  TaggedDocument(words=['much'], tags=[89]),
#  TaggedDocument(words=['passive'], tags=[90]),
#  TaggedDocument(words=['noise'], tags=[91]),
#  TaggedDocument(words=['deal'], tags=[92]),
#  TaggedDocument(words=['free'], tags=[93]),
#  TaggedDocument(words=['movie'], tags=[94]),
#  TaggedDocument(words=['vouches'], tags=[95]),
#  TaggedDocument(words=['posting'], tags=[96]),
#  TaggedDocument(words=['review'], tags=[97]),
#  TaggedDocument(words=['amazon'], tags=[98]),
#  TaggedDocument(words=['are'], tags=[99]),
#  TaggedDocument(words=['kidding'], tags=[100]),
#  TaggedDocument(words=['crossbeats'], tags=[101]),
#  TaggedDocument(words=['have'], tags=[102]),
#  TaggedDocument(words=['returned'], tags=[103]),
#  TaggedDocument(words=['product'], tags=[104]),
#  TaggedDocument(words=['sound'], tags=[105]),
#  TaggedDocument(words=['output'], tags=[106]),
#  TaggedDocument(words=['music'], tags=[107]),
#  TaggedDocument(words=['quality'], tags=[108]),
#  TaggedDocument(words=['way'], tags=[109]),
#  TaggedDocument(words=['better'], tags=[110]),
#  TaggedDocument(words=['competitors'], tags=[111]),
#  TaggedDocument(words=['quality'], tags=[112]),
#  TaggedDocument(words=['decent'], tags=[113]),
#  TaggedDocument(words=['enough'], tags=[114]),
#  TaggedDocument(words=['could'], tags=[115]),
#  TaggedDocument(words=['better'], tags=[116]),
#  TaggedDocument(words=['mic'], tags=[117]),
#  TaggedDocument(words=['sometimes'], tags=[118]),
#  TaggedDocument(words=['sounds'], tags=[119]),
#  TaggedDocument(words=['muffled'], tags=[120]),
#  TaggedDocument(words=['cancellation'], tags=[121]),
#  TaggedDocument(words=['way'], tags=[122]),
#  TaggedDocument(words=['good'], tags=[123]),
#  TaggedDocument(words=['case'], tags=[124]),
#  TaggedDocument(words=['premium'], tags=[125]),
#  TaggedDocument(words=['green'], tags=[126]),
#  TaggedDocument(words=['far'], tags=[127]),
#  TaggedDocument(words=['better'], tags=[128]),
#  TaggedDocument(words=['earpods'], tags=[129]),
#  TaggedDocument(words=['light'], tags=[130]),
#  TaggedDocument(words=['snug'], tags=[131]),
#  TaggedDocument(words=['fit'], tags=[132]),
#  TaggedDocument(words=['easily'], tags=[133]),
#  TaggedDocument(words=['go'], tags=[134]),
#  TaggedDocument(words=['gym'], tags=[135]),
#  TaggedDocument(words=['wearing'], tags=[136]),
#  TaggedDocument(words=['exercise'], tags=[137]),
#  TaggedDocument(words=['whic'], tags=[138]),
#  TaggedDocument(words=['includes'], tags=[139]),
#  TaggedDocument(words=['running'], tags=[140]),
#  TaggedDocument(words=['dont'], tags=[141]),
#  TaggedDocument(words=['fall'], tags=[142]),
#  TaggedDocument(words=['wonderful'], tags=[143]),
#  TaggedDocument(words=['bit'], tags=[144]),
#  TaggedDocument(words=['skeptical'], tags=[145]),
#  TaggedDocument(words=['buying'], tags=[146]),
#  TaggedDocument(words=['performing'], tags=[147]),
#  TaggedDocument(words=['beyond'], tags=[148]),
#  TaggedDocument(words=['expectations'], tags=[149]),
#  TaggedDocument(words=['sleek'], tags=[150]),
#  TaggedDocument(words=['design'], tags=[151]),
#  TaggedDocument(words=['high'], tags=[152]),
#  TaggedDocument(words=['quality'], tags=[153]),
#  TaggedDocument(words=['audio'], tags=[154]),
#  TaggedDocument(words=['will'], tags=[155]),
#  TaggedDocument(words=['update'], tags=[156]),
#  TaggedDocument(words=['week'], tags=[157]),
#  TaggedDocument(words=['use'], tags=[158]),
#  TaggedDocument(words=['hi'], tags=[159]),
#  TaggedDocument(words=['hi'], tags=[160]),
#  TaggedDocument(words=['best'], tags=[161]),
#  TaggedDocument(words=['earbuds'], tags=[162]),
#  TaggedDocument(words=['rs'], tags=[163]),
#  TaggedDocument(words=['the'], tags=[164]),
#  TaggedDocument(words=['product'], tags=[165]),
#  TaggedDocument(words=['feels'], tags=[166]),
#  TaggedDocument(words=['premium'], tags=[167]),
#  TaggedDocument(words=['fit'], tags=[168]),
#  TaggedDocument(words=['earbuds'], tags=[169]),
#  TaggedDocument(words=['soo'], tags=[170]),
#  TaggedDocument(words=['like'], tags=[171]),
#  TaggedDocument(words=['wearing'], tags=[172]),
#  TaggedDocument(words=['it'], tags=[173]),
#  TaggedDocument(words=['light'], tags=[174]),
#  TaggedDocument(words=['sounds'], tags=[175]),
#  TaggedDocument(words=['good'], tags=[176]),
#  TaggedDocument(words=['bass'], tags=[177]),
#  TaggedDocument(words=['punchy'], tags=[178]),
#  TaggedDocument(words=['sound'], tags=[179]),
#  TaggedDocument(words=['stage'], tags=[180]),
#  TaggedDocument(words=['also'], tags=[181]),
#  TaggedDocument(words=['good'], tags=[182]),
#  TaggedDocument(words=['compared'], tags=[183]),
#  TaggedDocument(words=['must'], tags=[184]),
#  TaggedDocument(words=['buy'], tags=[185]),
#  TaggedDocument(words=['ur'], tags=[186]),
#  TaggedDocument(words=['budget'], tags=[187]),
#  TaggedDocument(words=['around'], tags=[188]),
#  TaggedDocument(words=['do'], tags=[189]),
#  TaggedDocument(words=['buy'], tags=[190]),
#  TaggedDocument(words=['waste'], tags=[191]),
#  TaggedDocument(words=['money'], tags=[192]),
#  TaggedDocument(words=['pathetic'], tags=[193]),
#  TaggedDocument(words=['earpods'], tags=[194]),
#  TaggedDocument(words=['one'], tags=[195]),
#  TaggedDocument(words=['side'], tags=[196]),
#  TaggedDocument(words=['worked'], tags=[197]),
#  TaggedDocument(words=['head'], tags=[198]),
#  TaggedDocument(words=['tilted'], tags=[199]),
#  TaggedDocument(words=['towards'], tags=[200]),
#  TaggedDocument(words=['one'], tags=[201]),
#  TaggedDocument(words=['side'], tags=[202]),
#  TaggedDocument(words=['as'], tags=[203]),
#  TaggedDocument(words=['soon'], tags=[204]),
#  TaggedDocument(words=['keep'], tags=[205]),
#  TaggedDocument(words=['head'], tags=[206]),
#  TaggedDocument(words=['straight'], tags=[207]),
#  TaggedDocument(words=['right'], tags=[208]),
#  TaggedDocument(words=['side'], tags=[209]),
#  TaggedDocument(words=['stops'], tags=[210]),
#  TaggedDocument(words=['working'], tags=[211]),
#  TaggedDocument(words=['it'], tags=[212]),
#  TaggedDocument(words=['frustrating'], tags=[213]),
#  TaggedDocument(words=['utter'], tags=[214]),
#  TaggedDocument(words=['waste'], tags=[215]),
#  TaggedDocument(words=['time'], tags=[216]),
#  TaggedDocument(words=['returned'], tags=[217]),
#  TaggedDocument(words=['worth'], tags=[218]),
#  TaggedDocument(words=['amount'], tags=[219]),
#  TaggedDocument(words=['if'], tags=[220]),
#  TaggedDocument(words=['selling'], tags=[221]),
#  TaggedDocument(words=['someone'], tags=[222]),
#  TaggedDocument(words=['item'], tags=[223]),
#  TaggedDocument(words=['worth'], tags=[224]),
#  TaggedDocument(words=['least'], tags=[225]),
#  TaggedDocument(words=['proper'], tags=[226]),
#  TaggedDocument(words=['quality'], tags=[227]),
#  TaggedDocument(words=['check'], tags=[228]),
#  TaggedDocument(words=['good'], tags=[229]),
#  TaggedDocument(words=['sound'], tags=[230]),
#  TaggedDocument(words=['quality'], tags=[231]),
#  TaggedDocument(words=['good'], tags=[232]),
#  TaggedDocument(words=['not'], tags=[233]),
#  TaggedDocument(words=['value'], tags=[234]),
#  TaggedDocument(words=['money'], tags=[235]),
#  TaggedDocument(words=['looks'], tags=[236]),
#  TaggedDocument(words=['sounds'], tags=[237]),
#  TaggedDocument(words=['like'], tags=[238]),
#  TaggedDocument(words=['cheap'], tags=[239]),
#  TaggedDocument(words=['china'], tags=[240]),
#  TaggedDocument(words=['product'], tags=[241]),
#  TaggedDocument(words=['cranky'], tags=[242]),
#  TaggedDocument(words=['sound'], tags=[243]),
#  TaggedDocument(words=['press'], tags=[244]),
#  TaggedDocument(words=['buttons'], tags=[245]),
#  TaggedDocument(words=['next'], tags=[246]),
#  TaggedDocument(words=['track'], tags=[247]),
#  TaggedDocument(words=['also'], tags=[248]),
#  TaggedDocument(words=['fits'], tags=[249]),
#  TaggedDocument(words=['comfortable'], tags=[250]),
#  TaggedDocument(words=['ears'], tags=[251]),
#  TaggedDocument(words=['also'], tags=[252]),
#  TaggedDocument(words=['earbuds'], tags=[253]),
#  TaggedDocument(words=['rubber'], tags=[254]),
#  TaggedDocument(words=['quality'], tags=[255]),
#  TaggedDocument(words=['poor'], tags=[256]),
#  TaggedDocument(words=['pretty'], tags=[257]),
#  TaggedDocument(words=['bad'], tags=[258]),
#  TaggedDocument(words=['performance'], tags=[259]),
#  TaggedDocument(words=['bass'], tags=[260]),
#  TaggedDocument(words=['treble'], tags=[261]),
#  TaggedDocument(words=['hurts'], tags=[262]),
#  TaggedDocument(words=['ears'], tags=[263]),
#  TaggedDocument(words=['ordinary'], tags=[264]),
#  TaggedDocument(words=['sound'], tags=[265]),
#  TaggedDocument(words=['ordinary'], tags=[266]),
#  TaggedDocument(words=['bass'], tags=[267]),
#  TaggedDocument(words=['ordinary'], tags=[268]),
#  TaggedDocument(words=['fit'], tags=[269]),
#  TaggedDocument(words=['everything'], tags=[270]),
#  TaggedDocument(words=['ordinary'], tags=[271]),
#  TaggedDocument(words=['earphones'], tags=[272]),
#  TaggedDocument(words=['purchased'], tags=[273]),
#  TaggedDocument(words=['reading'], tags=[274]),
#  TaggedDocument(words=['good'], tags=[275]),
#  TaggedDocument(words=['reviews'], tags=[276]),
#  TaggedDocument(words=['using'], tags=[277]),
#  TaggedDocument(words=['around'], tags=[278]),
#  TaggedDocument(words=['min'], tags=[279]),
#  TaggedDocument(words=['wondered'], tags=[280]),
#  TaggedDocument(words=['wrong'], tags=[281]),
#  TaggedDocument(words=['people'], tags=[282]),
#  TaggedDocument(words=['giving'], tags=[283]),
#  TaggedDocument(words=['good'], tags=[284]),
#  TaggedDocument(words=['reviews'], tags=[285]),
#  TaggedDocument(words=['definitely'], tags=[286]),
#  TaggedDocument(words=['trust'], tags=[287]),
#  TaggedDocument(words=['bad'], tags=[288]),
#  TaggedDocument(words=['reviews'], tags=[289]),
#  TaggedDocument(words=['expect'], tags=[290]),
#  TaggedDocument(words=['better'], tags=[291]),
#  TaggedDocument(words=['performance'], tags=[292]),
#  TaggedDocument(words=['buying'], tags=[293]),
#  TaggedDocument(words=['earphones'], tags=[294]),
#  TaggedDocument(words=['audio'], tags=[295]),
#  TaggedDocument(words=['voice'], tags=[296]),
#  TaggedDocument(words=['yet'], tags=[297]),
#  TaggedDocument(words=['another'], tags=[298]),
#  TaggedDocument(words=['ear'], tags=[299]),
#  TaggedDocument(words=['piece'], tags=[300]),
#  TaggedDocument(words=['awesome'], tags=[301]),
#  TaggedDocument(words=['audio'], tags=[302]),
#  TaggedDocument(words=['scores'], tags=[303]),
#  TaggedDocument(words=['zero'], tags=[304]),
#  TaggedDocument(words=['call'], tags=[305]),
#  TaggedDocument(words=['quality'], tags=[306]),
#  TaggedDocument(words=['not'], tags=[307]),
#  TaggedDocument(words=['calls'], tags=[308]),
#  TaggedDocument(words=['workout'], tags=[309]),
#  TaggedDocument(words=['workout'], tags=[310]),
#  TaggedDocument(words=['no'], tags=[311]),
#  TaggedDocument(words=['falls'], tags=[312]),
#  TaggedDocument(words=['tried'], tags=[313]),
#  TaggedDocument(words=['pairs'], tags=[314]),
#  TaggedDocument(words=['one'], tags=[315]),
#  TaggedDocument(words=['star'], tags=[316]),
#  TaggedDocument(words=['market'], tags=[317]),
#  TaggedDocument(words=['perfect'], tags=[318]),
#  TaggedDocument(words=['working'], tags=[319]),
#  TaggedDocument(words=['even'], tags=[320]),
#  TaggedDocument(words=['extreme'], tags=[321]),
#  TaggedDocument(words=['quiet'], tags=[322]),
#  TaggedDocument(words=['person'], tags=[323]),
#  TaggedDocument(words=['struggle'], tags=[324]),
#  TaggedDocument(words=['hear'], tags=[325]),
#  TaggedDocument(words=['the'], tags=[326]),
#  TaggedDocument(words=['mic'], tags=[327]),
#  TaggedDocument(words=['big'], tags=[328]),
#  TaggedDocument(words=['sticks'], tags=[329]),
#  TaggedDocument(words=['ear'], tags=[330]),
#  TaggedDocument(words=['does'], tags=[331]),
#  TaggedDocument(words=['fit'], tags=[332]),
#  TaggedDocument(words=['like'], tags=[333]),
#  TaggedDocument(words=['shown'], tags=[334]),
#  TaggedDocument(words=['pictures'], tags=[335]),
#  TaggedDocument(words=['it'], tags=[336]),
#  TaggedDocument(words=['clearly'], tags=[337]),
#  TaggedDocument(words=['visible'], tags=[338]),
#  TaggedDocument(words=['almost'], tags=[339]),
#  TaggedDocument(words=['looks'], tags=[340]),
#  TaggedDocument(words=['like'], tags=[341]),
#  TaggedDocument(words=['idea'], tags=[342]),
#  TaggedDocument(words=['listento'], tags=[343]),
#  TaggedDocument(words=['music'], tags=[344]),
#  TaggedDocument(words=['sound'], tags=[345]),
#  TaggedDocument(words=['crisp'], tags=[346]),
#  TaggedDocument(words=['bass'], tags=[347]),
#  TaggedDocument(words=['bluetooth'], tags=[348]),
#  TaggedDocument(words=['auto'], tags=[349]),
#  TaggedDocument(words=['connects'], tags=[350]),
#  TaggedDocument(words=['one'], tags=[351]),
#  TaggedDocument(words=['earphone'], tags=[352]),
#  TaggedDocument(words=['value'], tags=[353]),
#  TaggedDocument(words=['money'], tags=[354]),
#  TaggedDocument(words=['wait'], tags=[355]),
#  TaggedDocument(words=['better'], tags=[356]),
#  TaggedDocument(words=['options'], tags=[357]),
#  TaggedDocument(words=['buy'], tags=[358]),
#  TaggedDocument(words=['brands'], tags=[359]),
#  TaggedDocument(words=['passed'], tags=[360]),
#  TaggedDocument(words=['deadline'], tags=[361]),
#  TaggedDocument(words=['return'], tags=[362]),
#  TaggedDocument(words=['product'], tags=[363]),
#  TaggedDocument(words=['stuck'], tags=[364]),
#  TaggedDocument(words=['use'], tags=[365]),
#  TaggedDocument(words=['listen'], tags=[366]),
#  TaggedDocument(words=['music'], tags=[367]),
#  TaggedDocument(words=['alright'], tags=[368]),
#  TaggedDocument(words=['okay'], tags=[369]),
#  TaggedDocument(words=['price'], tags=[370]),
#  TaggedDocument(words=['point'], tags=[371]),
#  TaggedDocument(words=['if'], tags=[372]),
#  TaggedDocument(words=['finicky'], tags=[373]),
#  TaggedDocument(words=['audio'], tags=[374]),
#  TaggedDocument(words=['quality'], tags=[375]),
#  TaggedDocument(words=['pros'], tags=[376]),
#  TaggedDocument(words=['the'], tags=[377]),
#  TaggedDocument(words=['design'], tags=[378]),
#  TaggedDocument(words=['case'], tags=[379]),
#  TaggedDocument(words=['headphones'], tags=[380]),
#  TaggedDocument(words=['amazing'], tags=[381]),
#  TaggedDocument(words=['looks'], tags=[382]),
#  TaggedDocument(words=['sleek'], tags=[383]),
#  TaggedDocument(words=['build'], tags=[384]),
#  TaggedDocument(words=['light'], tags=[385]),
#  TaggedDocument(words=['weight'], tags=[386]),
#  TaggedDocument(words=['barely'], tags=[387]),
#  TaggedDocument(words=['feel'], tags=[388]),
#  TaggedDocument(words=['the'], tags=[389]),
#  TaggedDocument(words=['button'], tags=[390]),
#  TaggedDocument(words=['controls'], tags=[391]),
#  TaggedDocument(words=['pretty'], tags=[392]),
#  TaggedDocument(words=['battery'], tags=[393]),
#  TaggedDocument(words=['life'], tags=[394]),
#  TaggedDocument(words=['adequate'], tags=[395]),
#  TaggedDocument(words=['average'], tags=[396]),
#  TaggedDocument(words=['userscons'], tags=[397]),
#  TaggedDocument(words=['audio'], tags=[398]),
#  TaggedDocument(words=['quality'], tags=[399]),
#  TaggedDocument(words=['quite'], tags=[400]),
#  TaggedDocument(words=['average'], tags=[401]),
#  TaggedDocument(words=['specially'], tags=[402]),
#  TaggedDocument(words=['compared'], tags=[403]),
#  TaggedDocument(words=['products'], tags=[404]),
#  TaggedDocument(words=['crossbeats'], tags=[405]),
#  TaggedDocument(words=['there'], tags=[406]),
#  TaggedDocument(words=['noise'], tags=[407]),
#  TaggedDocument(words=['cancellation'], tags=[408]),
#  TaggedDocument(words=['overall'], tags=[409]),
#  TaggedDocument(words=['sound'], tags=[410]),
#  TaggedDocument(words=['quality'], tags=[411]),
#  TaggedDocument(words=['calls'], tags=[412]),
#  TaggedDocument(words=['badit'], tags=[413]),
#  TaggedDocument(words=['still'], tags=[414]),
#  TaggedDocument(words=['decent'], tags=[415]),
#  TaggedDocument(words=['product'], tags=[416]),
#  TaggedDocument(words=['sound'], tags=[417]),
#  TaggedDocument(words=['quality'], tags=[418]),
#  TaggedDocument(words=['think'], tags=[419]),
#  TaggedDocument(words=['overpriced'], tags=[420]),
#  TaggedDocument(words=['bang'], tags=[421]),
#  TaggedDocument(words=['buck'], tags=[422]),
#  TaggedDocument(words=['wireless'], tags=[423]),
#  TaggedDocument(words=['marvel'], tags=[424]),
#  TaggedDocument(words=['when'], tags=[425]),
#  TaggedDocument(words=['people'], tags=[426]),
#  TaggedDocument(words=['praised'], tags=[427]),
#  TaggedDocument(words=['look'], tags=[428]),
#  TaggedDocument(words=['earphones'], tags=[429]),
#  TaggedDocument(words=['sky'], tags=[430]),
#  TaggedDocument(words=['though'], tags=[431]),
#  TaggedDocument(words=['kidding'], tags=[432]),
#  TaggedDocument(words=['these'], tags=[433]),
#  TaggedDocument(words=['really'], tags=[434]),
#  TaggedDocument(words=['adorable'], tags=[435]),
#  TaggedDocument(words=['ear'], tags=[436]),
#  TaggedDocument(words=['pieces'], tags=[437]),
#  TaggedDocument(words=['pair'], tags=[438]),
#  TaggedDocument(words=['amazingly'], tags=[439]),
#  TaggedDocument(words=['quickly'], tags=[440]),
#  TaggedDocument(words=['tab'], tags=[441]),
#  TaggedDocument(words=['phone'], tags=[442]),
#  TaggedDocument(words=['using'], tags=[443]),
#  TaggedDocument(words=['bt'], tags=[444]),
#  TaggedDocument(words=['the'], tags=[445]),
#  TaggedDocument(words=['sound'], tags=[446]),
#  TaggedDocument(words=['quality'], tags=[447]),
#  TaggedDocument(words=['stunning'], tags=[448]),
#  TaggedDocument(words=['right'], tags=[449]),
#  TaggedDocument(words=['levels'], tags=[450]),
#  TaggedDocument(words=['bass'], tags=[451]),
#  TaggedDocument(words=['treble'], tags=[452]),
#  TaggedDocument(words=['however'], tags=[453]),
#  TaggedDocument(words=['sometimes'], tags=[454]),
#  TaggedDocument(words=['calls'], tags=[455]),
#  TaggedDocument(words=['need'], tags=[456]),
#  TaggedDocument(words=['hold'], tags=[457]),
#  TaggedDocument(words=['one'], tags=[458]),
#  TaggedDocument(words=['ear'], tags=[459]),
#  TaggedDocument(words=['piece'], tags=[460]),
#  TaggedDocument(words=['near'], tags=[461]),
#  TaggedDocument(words=['mouth'], tags=[462]),
#  TaggedDocument(words=['loud'], tags=[463]),
#  TaggedDocument(words=['enough'], tags=[464]),
#  TaggedDocument(words=['dual'], tags=[465]),
#  TaggedDocument(words=['mics'], tags=[466]),
#  TaggedDocument(words=['ear'], tags=[467]),
#  TaggedDocument(words=['pieces'], tags=[468]),
#  TaggedDocument(words=['pick'], tags=[469]),
#  TaggedDocument(words=['voice'], tags=[470]),
#  TaggedDocument(words=['so'], tags=[471]),
#  TaggedDocument(words=['low'], tags=[472]),
#  TaggedDocument(words=['tone'], tags=[473]),
#  TaggedDocument(words=['mushy'], tags=[474]),
#  TaggedDocument(words=['calls'], tags=[475]),
#  TaggedDocument(words=['hehe'], tags=[476]),
#  TaggedDocument(words=['low'], tags=[477]),
#  TaggedDocument(words=['latency'], tags=[478]),
#  TaggedDocument(words=['means'], tags=[479]),
#  TaggedDocument(words=['video'], tags=[480]),
#  TaggedDocument(words=['viewing'], tags=[481]),
#  TaggedDocument(words=['without'], tags=[482]),
#  TaggedDocument(words=['audio'], tags=[483]),
#  TaggedDocument(words=['lag'], tags=[484]),
#  TaggedDocument(words=['love'], tags=[485]),
#  TaggedDocument(words=['charge'], tags=[486]),
#  TaggedDocument(words=['cute'], tags=[487]),
#  TaggedDocument(words=['little'], tags=[488]),
#  TaggedDocument(words=['case'], tags=[489]),
#  TaggedDocument(words=['every'], tags=[490]),
#  TaggedDocument(words=['time'], tags=[491]),
#  TaggedDocument(words=['put'], tags=[492]),
#  TaggedDocument(words=['ready'], tags=[493]),
#  TaggedDocument(words=['next'], tags=[494]),
#  TaggedDocument(words=['listen'], tags=[495]),
#  TaggedDocument(words=['the'], tags=[496]),
#  TaggedDocument(words=['case'], tags=[497]),
#  TaggedDocument(words=['easily'], tags=[498]),
#  TaggedDocument(words=['fit'], tags=[499]),
#  TaggedDocument(words=['pocket'], tags=[500]),
#  TaggedDocument(words=['quite'], tags=[501]),
#  TaggedDocument(words=['sturdy'], tags=[502]),
#  TaggedDocument(words=['super'], tags=[503]),
#  TaggedDocument(words=['portable'], tags=[504]),
#  TaggedDocument(words=['you'], tags=[505]),
#  TaggedDocument(words=['never'], tags=[506]),
#  TaggedDocument(words=['run'], tags=[507]),
#  TaggedDocument(words=['offer'], tags=[508]),
#  TaggedDocument(words=['grreat'], tags=[509]),
#  TaggedDocument(words=['value'], tags=[510]),
#  TaggedDocument(words=['money'], tags=[511]),
#  TaggedDocument(words=['the'], tags=[512]),
#  TaggedDocument(words=['case'], tags=[513]),
#  TaggedDocument(words=['also'], tags=[514]),
#  TaggedDocument(words=['type'], tags=[515]),
#  TaggedDocument(words=['fast'], tags=[516]),
#  TaggedDocument(words=['charging'], tags=[517]),
#  TaggedDocument(words=['unit'], tags=[518]),
#  TaggedDocument(words=['yet'], tags=[519]),
#  TaggedDocument(words=['try'], tags=[520]),
#  TaggedDocument(words=['use'], tags=[521]),
#  TaggedDocument(words=['charger'], tags=[522]),
#  TaggedDocument(words=['power'], tags=[523]),
#  TaggedDocument(words=['bank'], tags=[524]),
#  TaggedDocument(words=['do'], tags=[525]),
#  TaggedDocument(words=['fall'], tags=[526]),
#  TaggedDocument(words=['paid'], tags=[527]),
#  TaggedDocument(words=['positive'], tags=[528]),
#  TaggedDocument(words=['reviews'], tags=[529]),
#  TaggedDocument(words=['first'], tags=[530]),
#  TaggedDocument(words=['would'], tags=[531]),
#  TaggedDocument(words=['like'], tags=[532]),
#  TaggedDocument(words=['warn'], tags=[533]),
#  TaggedDocument(words=['positive'], tags=[534]),
#  TaggedDocument(words=['reviews'], tags=[535]),
#  TaggedDocument(words=['paid'], tags=[536]),
#  TaggedDocument(words=['reviews'], tags=[537]),
#  TaggedDocument(words=['incentive'], tags=[538]),
#  TaggedDocument(words=['months'], tags=[539]),
#  TaggedDocument(words=['ganna'], tags=[540]),
#  TaggedDocument(words=['subscription'], tags=[541]),
#  TaggedDocument(words=['as'], tags=[542]),
#  TaggedDocument(words=['soon'], tags=[543]),
#  TaggedDocument(words=['register'], tags=[544]),
#  TaggedDocument(words=['product'], tags=[545]),
#  TaggedDocument(words=['warranty'], tags=[546]),
#  TaggedDocument(words=['start'], tags=[547]),
#  TaggedDocument(words=['getting'], tags=[548]),
#  TaggedDocument(words=['whatsapp'], tags=[549]),
#  TaggedDocument(words=['messages'], tags=[550]),
#  TaggedDocument(words=['calls'], tags=[551]),
#  TaggedDocument(words=['crossbeats'], tags=[552]),
#  TaggedDocument(words=['customer'], tags=[553]),
#  TaggedDocument(words=['representative'], tags=[554]),
#  TaggedDocument(words=['number'], tags=[555]),
#  TaggedDocument(words=['continuously'], tags=[556]),
#  TaggedDocument(words=['asking'], tags=[557]),
#  TaggedDocument(words=['send'], tags=[558]),
#  TaggedDocument(words=['screenshot'], tags=[559]),
#  TaggedDocument(words=['positive'], tags=[560]),
#  TaggedDocument(words=['review'], tags=[561]),
#  TaggedDocument(words=['exchange'], tags=[562]),
#  TaggedDocument(words=['months'], tags=[563]),
#  TaggedDocument(words=['gaana'], tags=[564]),
#  TaggedDocument(words=['subscription'], tags=[565]),
#  TaggedDocument(words=['they'], tags=[566]),
#  TaggedDocument(words=['dedicated'], tags=[567]),
#  TaggedDocument(words=['channel'], tags=[568]),
#  TaggedDocument(words=['pushing'], tags=[569]),
#  TaggedDocument(words=['customers'], tags=[570]),
#  TaggedDocument(words=['give'], tags=[571]),
#  TaggedDocument(words=['positive'], tags=[572]),
#  TaggedDocument(words=['reviews'], tags=[573]),
#  TaggedDocument(words=['case'], tags=[574]),
#  TaggedDocument(words=['face'], tags=[575]),
#  TaggedDocument(words=['issue'], tags=[576]),
#  TaggedDocument(words=['way'], tags=[577]),
#  TaggedDocument(words=['directly'], tags=[578]),
#  TaggedDocument(words=['talk'], tags=[579]),
#  TaggedDocument(words=['customer'], tags=[580]),
#  TaggedDocument(words=['representative'], tags=[581]),
#  TaggedDocument(words=['resolve'], tags=[582]),
#  TaggedDocument(words=['you'], tags=[583]),
#  TaggedDocument(words=['send'], tags=[584]),
#  TaggedDocument(words=['mail'], tags=[585]),
#  TaggedDocument(words=['support'], tags=[586]),
#  TaggedDocument(words=['wait'], tags=[587]),
#  TaggedDocument(words=['hours'], tags=[588]),
#  TaggedDocument(words=['reply'], tags=[589]),
#  TaggedDocument(words=['first'], tags=[590]),
#  TaggedDocument(words=['mail'], tags=[591]),
#  TaggedDocument(words=['reply'], tags=[592]),
#  TaggedDocument(words=['ask'], tags=[593]),
#  TaggedDocument(words=['invoice'], tags=[594]),
#  TaggedDocument(words=['product'], tags=[595]),
#  TaggedDocument(words=['details'], tags=[596]),
#  TaggedDocument(words=['even'], tags=[597]),
#  TaggedDocument(words=['though'], tags=[598]),
#  TaggedDocument(words=['sending'], tags=[599]),
#  TaggedDocument(words=['mail'], tags=[600]),
#  TaggedDocument(words=['mail'], tags=[601]),
#  TaggedDocument(words=['id'], tags=[602]),
#  TaggedDocument(words=['product'], tags=[603]),
#  TaggedDocument(words=['registered'], tags=[604]),
#  TaggedDocument(words=['in'], tags=[605]),
#  TaggedDocument(words=['second'], tags=[606]),
#  TaggedDocument(words=['mail'], tags=[607]),
#  TaggedDocument(words=['ask'], tags=[608]),
#  TaggedDocument(words=['restart'], tags=[609]),
#  TaggedDocument(words=['bud'], tags=[610]),
#  TaggedDocument(words=['check'], tags=[611]),
#  TaggedDocument(words=['resolves'], tags=[612]),
#  TaggedDocument(words=['issue'], tags=[613]),
#  TaggedDocument(words=['third'], tags=[614]),
#  TaggedDocument(words=['mail'], tags=[615]),
#  TaggedDocument(words=['ask'], tags=[616]),
#  TaggedDocument(words=['record'], tags=[617]),
#  TaggedDocument(words=['video'], tags=[618]),
#  TaggedDocument(words=['problem'], tags=[619]),
#  TaggedDocument(words=['send'], tags=[620]),
#  TaggedDocument(words=['facing'], tags=[621]),
#  TaggedDocument(words=['audio'], tags=[622]),
#  TaggedDocument(words=['connectivity'], tags=[623]),
#  TaggedDocument(words=['issue'], tags=[624]),
#  TaggedDocument(words=['still'], tags=[625]),
#  TaggedDocument(words=['asked'], tags=[626]),
#  TaggedDocument(words=['send'], tags=[627]),
#  TaggedDocument(words=['video'], tags=[628]),
#  TaggedDocument(words=['know'], tags=[629]),
#  TaggedDocument(words=['record'], tags=[630]),
#  TaggedDocument(words=['video'], tags=[631]),
#  TaggedDocument(words=['so'], tags=[632]),
#  TaggedDocument(words=['average'], tags=[633]),
#  TaggedDocument(words=['almost'], tags=[634]),
#  TaggedDocument(words=['week'], tags=[635]),
#  TaggedDocument(words=['till'], tags=[636]),
#  TaggedDocument(words=['get'], tags=[637]),
#  TaggedDocument(words=['actual'], tags=[638]),
#  TaggedDocument(words=['response'], tags=[639]),
#  TaggedDocument(words=['problem'], tags=[640]),
#  TaggedDocument(words=['now'], tags=[641]),
#  TaggedDocument(words=['whether'], tags=[642]),
#  TaggedDocument(words=['actually'], tags=[643]),
#  TaggedDocument(words=['help'], tags=[644]),
#  TaggedDocument(words=['another'], tags=[645]),
#  TaggedDocument(words=['connectivity'], tags=[646]),
#  TaggedDocument(words=['issue'], tags=[647]),
#  TaggedDocument(words=['audio'], tags=[648]),
#  TaggedDocument(words=['output'], tags=[649]),
#  TaggedDocument(words=['right'], tags=[650]),
#  TaggedDocument(words=['bud'], tags=[651]),
#  TaggedDocument(words=['getting'], tags=[652]),
#  TaggedDocument(words=['disrupted'], tags=[653]),
#  TaggedDocument(words=['frequently'], tags=[654]),
#  TaggedDocument(words=['it'], tags=[655]),
#  TaggedDocument(words=['split'], tags=[656]),
#  TaggedDocument(words=['second'], tags=[657]),
#  TaggedDocument(words=['every'], tags=[658]),
#  TaggedDocument(words=['seconds'], tags=[659]),
#  TaggedDocument(words=['repeating'], tags=[660]),
#  TaggedDocument(words=['like'], tags=[661]),
#  TaggedDocument(words=['irritating'], tags=[662]),
#  TaggedDocument(words=['and'], tags=[663]),
#  TaggedDocument(words=['response'], tags=[664]),
#  TaggedDocument(words=['finally'], tags=[665]),
#  TaggedDocument(words=['got'], tags=[666]),
#  TaggedDocument(words=['one'], tags=[667]),
#  TaggedDocument(words=['week'], tags=[668]),
#  TaggedDocument(words=['this'], tags=[669]),
#  TaggedDocument(words=['standard'], tags=[670]),
#  TaggedDocument(words=['across'], tags=[671]),
#  TaggedDocument(words=['bluetooth'], tags=[672]),
#  TaggedDocument(words=['powered'], tags=[673]),
#  TaggedDocument(words=['devices'], tags=[674]),
#  TaggedDocument(words=['told'], tags=[675]),
#  TaggedDocument(words=['wifi'], tags=[676]),
#  TaggedDocument(words=['bluetooth'], tags=[677]),
#  TaggedDocument(words=['connection'], tags=[678]),
#  TaggedDocument(words=['getting'], tags=[679]),
#  TaggedDocument(words=['disrupted'], tags=[680]),
#  TaggedDocument(words=['normal'], tags=[681]),
#  TaggedDocument(words=['but'], tags=[682]),
#  TaggedDocument(words=['replied'], tags=[683]),
#  TaggedDocument(words=['using'], tags=[684]),
#  TaggedDocument(words=['bluetooth'], tags=[685]),
#  TaggedDocument(words=['earphone'], tags=[686]),
#  TaggedDocument(words=['bluetooth'], tags=[687]),
#  TaggedDocument(words=['speaker'], tags=[688]),
#  TaggedDocument(words=['brands'], tags=[689]),
#  TaggedDocument(words=['years'], tags=[690]),
#  TaggedDocument(words=['never'], tags=[691]),
#  TaggedDocument(words=['faced'], tags=[692]),
#  TaggedDocument(words=['issue'], tags=[693]),
#  TaggedDocument(words=['surely'], tags=[694]),
#  TaggedDocument(words=['standard'], tags=[695]),
#  TaggedDocument(words=['bluetooth'], tags=[696]),
#  TaggedDocument(words=['devices'], tags=[697]),
#  TaggedDocument(words=['even'], tags=[698]),
#  TaggedDocument(words=['left'], tags=[699]),
#  TaggedDocument(words=['bud'], tags=[700]),
#  TaggedDocument(words=['working'], tags=[701]),
#  TaggedDocument(words=['fine'], tags=[702]),
#  TaggedDocument(words=['right'], tags=[703]),
#  TaggedDocument(words=['one'], tags=[704]),
#  TaggedDocument(words=['problem'], tags=[705]),
#  TaggedDocument(words=['got'], tags=[706]),
#  TaggedDocument(words=['reply'], tags=[707]),
#  TaggedDocument(words=['since'], tags=[708]),
#  TaggedDocument(words=['bought'], tags=[709]),
#  TaggedDocument(words=['less'], tags=[710]),
#  TaggedDocument(words=['month'], tags=[711]),
#  TaggedDocument(words=['ago'], tags=[712]),
#  TaggedDocument(words=['asked'], tags=[713]),
#  TaggedDocument(words=['replacement'], tags=[714]),
#  TaggedDocument(words=['could'], tags=[715]),
#  TaggedDocument(words=['help'], tags=[716]),
#  TaggedDocument(words=['fix'], tags=[717]),
#  TaggedDocument(words=['issue'], tags=[718]),
#  TaggedDocument(words=['got'], tags=[719]),
#  TaggedDocument(words=['response'], tags=[720]),
#  TaggedDocument(words=['since'], tags=[721]),
#  TaggedDocument(words=['but'], tags=[722]),
#  TaggedDocument(words=['getting'], tags=[723]),
#  TaggedDocument(words=['positive'], tags=[724]),
#  TaggedDocument(words=['review'], tags=[725]),
#  TaggedDocument(words=['send'], tags=[726]),
#  TaggedDocument(words=['whatsapp'], tags=[727]),
#  TaggedDocument(words=['reminder'], tags=[728]),
#  TaggedDocument(words=['everyday'], tags=[729]),
#  TaggedDocument(words=['call'], tags=[730]),
#  TaggedDocument(words=['every'], tags=[731]),
#  TaggedDocument(words=['alternate'], tags=[732]),
#  TaggedDocument(words=['day'], tags=[733]),
#  TaggedDocument(words=['without'], tags=[734]),
#  TaggedDocument(words=['fail'], tags=[735]),
#  TaggedDocument(words=['rip'], tags=[736]),
#  TaggedDocument(words=['it'], tags=[737]),
#  TaggedDocument(words=['rip'], tags=[738]),
#  TaggedDocument(words=['offits'], tags=[739]),
#  TaggedDocument(words=['jus'], tags=[740]),
#  TaggedDocument(words=['good'], tags=[741]),
#  TaggedDocument(words=['looking'], tags=[742]),
#  TaggedDocument(words=['headphone'], tags=[743]),
#  TaggedDocument(words=['functionality'], tags=[744]),
#  TaggedDocument(words=['problemsi'], tags=[745]),
#  TaggedDocument(words=['regret'], tags=[746]),
#  TaggedDocument(words=['going'], tags=[747]),
#  TaggedDocument(words=['itnoise'], tags=[748]),
#  TaggedDocument(words=['cancellation'], tags=[749]),
#  TaggedDocument(words=['crappy'], tags=[750]),
#  TaggedDocument(words=['andvoice'], tags=[751]),
#  TaggedDocument(words=['echo'], tags=[752]),
#  TaggedDocument(words=['sorts'], tags=[753]),
#  TaggedDocument(words=['callsand'], tags=[754]),
#  TaggedDocument(words=['support'], tags=[755]),
#  TaggedDocument(words=['customer'], tags=[756]),
#  TaggedDocument(words=['care'], tags=[757]),
#  TaggedDocument(words=['the'], tags=[758]),
#  TaggedDocument(words=['design'], tags=[759]),
#  TaggedDocument(words=['look'], tags=[760]),
#  TaggedDocument(words=['earphones'], tags=[761]),
#  TaggedDocument(words=['amazing'], tags=[762]),
#  TaggedDocument(words=['it'], tags=[763]),
#  TaggedDocument(words=['got'], tags=[764]),
#  TaggedDocument(words=['good'], tags=[765]),
#  TaggedDocument(words=['battery'], tags=[766]),
#  TaggedDocument(words=['life'], tags=[767]),
#  TaggedDocument(words=['handy'], tags=[768]),
#  TaggedDocument(words=['device'], tags=[769]),
#  TaggedDocument(words=['decent'], tags=[770]),
#  TaggedDocument(words=['sound'], tags=[771]),
#  TaggedDocument(words=['slick'], tags=[772]),
#  TaggedDocument(words=['design'], tags=[773]),
#  TaggedDocument(words=['connection'], tags=[774]),
#  TaggedDocument(words=['reset'], tags=[775]),
#  TaggedDocument(words=['guide'], tags=[776]),
#  TaggedDocument(words=['given'], tags=[777]),
#  TaggedDocument(words=['the'], tags=[778]),
#  TaggedDocument(words=['microphone'], tags=[779]),
#  TaggedDocument(words=['horrible'], tags=[780]),
#  TaggedDocument(words=['constant'], tags=[781]),
#  TaggedDocument(words=['noise'], tags=[782]),
#  TaggedDocument(words=['receiving'], tags=[783]),
#  TaggedDocument(words=['end'], tags=[784]),
#  TaggedDocument(words=['hard'], tags=[785]),
#  TaggedDocument(words=['time'], tags=[786]),
#  TaggedDocument(words=['connecting'], tags=[787]),
#  TaggedDocument(words=['device'], tags=[788]),
#  TaggedDocument(words=['fails'], tags=[789]),
#  TaggedDocument(words=['detect'], tags=[790]),
#  TaggedDocument(words=['individual'], tags=[791]),
#  TaggedDocument(words=['price'], tags=[792]),
#  TaggedDocument(words=['high'], tags=[793]),
#  TaggedDocument(words=['compare'], tags=[794]),
#  TaggedDocument(words=['basic'], tags=[795]),
#  TaggedDocument(words=['services'], tags=[796]),
#  TaggedDocument(words=['bass'], tags=[797]),
#  TaggedDocument(words=['one'], tags=[798]),
#  TaggedDocument(words=['would'], tags=[799]),
#  TaggedDocument(words=['expect'], tags=[800]),
#  TaggedDocument(words=['hint'], tags=[801]),
#  TaggedDocument(words=['bass'], tags=[802]),
#  TaggedDocument(words=['needs'], tags=[803]),
#  TaggedDocument(words=['high'], tags=[804]),
#  TaggedDocument(words=['great'], tags=[805]),
#  TaggedDocument(words=['audio'], tags=[806]),
#  TaggedDocument(words=['quality'], tags=[807]),
#  TaggedDocument(words=['battery'], tags=[808]),
#  TaggedDocument(words=['life'], tags=[809]),
#  TaggedDocument(words=['looks'], tags=[810]),
#  TaggedDocument(words=['price'], tags=[811]),
#  TaggedDocument(words=['range'], tags=[812]),
#  TaggedDocument(words=['for'], tags=[813]),
#  TaggedDocument(words=['details'], tags=[814]),
#  TaggedDocument(words=['read'], tags=[815]),
#  TaggedDocument(words=['pros'], tags=[816]),
#  TaggedDocument(words=['product'], tags=[817]),
#  TaggedDocument(words=['made'], tags=[818]),
#  TaggedDocument(words=['india'], tags=[819]),
#  TaggedDocument(words=['indian'], tags=[820]),
#  TaggedDocument(words=['origin'], tags=[821]),
#  TaggedDocument(words=['startup'], tags=[822]),
#  TaggedDocument(words=['looks'], tags=[823]),
#  TaggedDocument(words=['awesome'], tags=[824]),
#  TaggedDocument(words=['looking'], tags=[825]),
#  TaggedDocument(words=['earbuds'], tags=[826]),
#  TaggedDocument(words=['sleek'], tags=[827]),
#  TaggedDocument(words=['chic'], tags=[828]),
#  TaggedDocument(words=['charging'], tags=[829]),
#  TaggedDocument(words=['case'], tags=[830]),
#  TaggedDocument(words=['good'], tags=[831]),
#  TaggedDocument(words=['battery'], tags=[832]),
#  TaggedDocument(words=['fast'], tags=[833]),
#  TaggedDocument(words=['charging'], tags=[834]),
#  TaggedDocument(words=['charging'], tags=[835]),
#  TaggedDocument(words=['big'], tags=[836]),
#  TaggedDocument(words=['plus'], tags=[837]),
#  TaggedDocument(words=['point'], tags=[838]),
#  TaggedDocument(words=['very'], tags=[839]),
#  TaggedDocument(words=['good'], tags=[840]),
#  TaggedDocument(words=['audio'], tags=[841]),
#  TaggedDocument(words=['quality'], tags=[842]),
#  TaggedDocument(words=['especially'], tags=[843]),
#  TaggedDocument(words=['very'], tags=[844]),
#  TaggedDocument(words=['good'], tags=[845]),
#  TaggedDocument(words=['very'], tags=[846]),
#  TaggedDocument(words=['good'], tags=[847]),
#  TaggedDocument(words=['audio'], tags=[848]),
#  TaggedDocument(words=['person'], tags=[849]),
#  TaggedDocument(words=['calling'], tags=[850]),
#  TaggedDocument(words=['bad'], tags=[851]),
#  TaggedDocument(words=['audio'], tags=[852]),
#  TaggedDocument(words=['us'], tags=[853]),
#  TaggedDocument(words=['person'], tags=[854]),
#  TaggedDocument(words=['button'], tags=[855]),
#  TaggedDocument(words=['makes'], tags=[856]),
#  TaggedDocument(words=['kinda'], tags=[857]),
#  TaggedDocument(words=['loud'], tags=[858]),
#  TaggedDocument(words=['sound'], tags=[859]),
#  TaggedDocument(words=['pressed'], tags=[860]),
#  TaggedDocument(words=['earbuds'], tags=[861]),
#  TaggedDocument(words=['earverdict'], tags=[862]),
#  TaggedDocument(words=['great'], tags=[863]),
#  TaggedDocument(words=['audio'], tags=[864]),
#  TaggedDocument(words=['quality'], tags=[865]),
#  TaggedDocument(words=['great'], tags=[866]),
#  TaggedDocument(words=['battery'], tags=[867]),
#  TaggedDocument(words=['life'], tags=[868]),
#  TaggedDocument(words=['great'], tags=[869]),
#  TaggedDocument(words=['looks'], tags=[870]),
#  TaggedDocument(words=['price'], tags=[871]),
#  TaggedDocument(words=['range'], tags=[872]),
#  TaggedDocument(words=['got'], tags=[873]),
#  TaggedDocument(words=['cheated'], tags=[874]),
#  TaggedDocument(words=['fake'], tags=[875]),
#  TaggedDocument(words=['youtubers'], tags=[876]),
#  TaggedDocument(words=['heard'], tags=[877]),
#  TaggedDocument(words=['great'], tags=[878]),
#  TaggedDocument(words=['reviews'], tags=[879]),
#  TaggedDocument(words=['product'], tags=[880]),
#  TaggedDocument(words=['youtubers'], tags=[881]),
#  TaggedDocument(words=['like'], tags=[882]),
#  TaggedDocument(words=['technology'], tags=[883]),
#  TaggedDocument(words=['jock'], tags=[884]),
#  TaggedDocument(words=['others'], tags=[885]),
#  TaggedDocument(words=['quite'], tags=[886]),
#  TaggedDocument(words=['interested'], tags=[887]),
#  TaggedDocument(words=['listening'], tags=[888]),
#  TaggedDocument(words=['highly'], tags=[889]),
#  TaggedDocument(words=['positive'], tags=[890]),
#  TaggedDocument(words=['views'], tags=[891]),
#  TaggedDocument(words=['product'], tags=[892]),
#  TaggedDocument(words=['later'], tags=[893]),
#  TaggedDocument(words=['receiving'], tags=[894]),
#  TaggedDocument(words=['understood'], tags=[895]),
#  TaggedDocument(words=['paid'], tags=[896]),
#  TaggedDocument(words=['promote'], tags=[897]),
#  TaggedDocument(words=['the'], tags=[898]),
#  TaggedDocument(words=['audio'], tags=[899]),
#  TaggedDocument(words=['quality'], tags=[900]),
#  TaggedDocument(words=['pathetic'], tags=[901]),
#  TaggedDocument(words=['like'], tags=[902]),
#  TaggedDocument(words=['cheap'], tags=[903]),
#  TaggedDocument(words=['chinese'], tags=[904]),
#  TaggedDocument(words=['wired'], tags=[905]),
#  TaggedDocument(words=['earphones'], tags=[906]),
#  TaggedDocument(words=['after'], tags=[907]),
#  TaggedDocument(words=['even'], tags=[908]),
#  TaggedDocument(words=['chinese'], tags=[909]),
#  TaggedDocument(words=['product'], tags=[910]),
#  TaggedDocument(words=['am'], tags=[911]),
#  TaggedDocument(words=['meaning'], tags=[912]),
#  TaggedDocument(words=['sound'], tags=[913]),
#  TaggedDocument(words=['biased'], tags=[914]),
#  TaggedDocument(words=['infact'], tags=[915]),
#  TaggedDocument(words=['using'], tags=[916]),
#  TaggedDocument(words=['chinese'], tags=[917]),
#  TaggedDocument(words=['products'], tags=[918]),
#  TaggedDocument(words=['garbage'], tags=[919]),
#  TaggedDocument(words=['not'], tags=[920]),
#  TaggedDocument(words=['worth'], tags=[921]),
#  TaggedDocument(words=['price'], tags=[922]),
#  TaggedDocument(words=['even'], tags=[923]),
#  TaggedDocument(words=['worth'], tags=[924]),
#  TaggedDocument(words=['the'], tags=[925]),
#  TaggedDocument(words=['quality'], tags=[926]),
#  TaggedDocument(words=['earbuds'], tags=[927]),
#  TaggedDocument(words=['plasticy'], tags=[928]),
#  TaggedDocument(words=['feels'], tags=[929]),
#  TaggedDocument(words=['delicate'], tags=[930]),
#  TaggedDocument(words=['even'], tags=[931]),
#  TaggedDocument(words=['fit'], tags=[932]),
#  TaggedDocument(words=['ear'], tags=[933]),
#  TaggedDocument(words=['properly'], tags=[934]),
#  TaggedDocument(words=['dont'], tags=[935]),
#  TaggedDocument(words=['buy'], tags=[936]),
#  TaggedDocument(words=['save'], tags=[937]),
#  TaggedDocument(words=['money'], tags=[938]),
#  TaggedDocument(words=['go'], tags=[939]),
#  TaggedDocument(words=['another'], tags=[940]),
#  TaggedDocument(words=['product'], tags=[941]),
#  TaggedDocument(words=['nice'], tags=[942]),
#  TaggedDocument(words=['product'], tags=[943]),
#  TaggedDocument(words=['this'], tags=[944]),
#  TaggedDocument(words=['first'], tags=[945]),
#  TaggedDocument(words=['tws'], tags=[946]),
#  TaggedDocument(words=['bluetooth'], tags=[947]),
#  TaggedDocument(words=['earbuds'], tags=[948]),
#  TaggedDocument(words=['lot'], tags=[949]),
#  TaggedDocument(words=['research'], tags=[950]),
#  TaggedDocument(words=['bought'], tags=[951]),
#  TaggedDocument(words=['connectivity'], tags=[952]),
#  TaggedDocument(words=['swift'], tags=[953]),
#  TaggedDocument(words=['moment'], tags=[954]),
#  TaggedDocument(words=['taken'], tags=[955]),
#  TaggedDocument(words=['case'], tags=[956]),
#  TaggedDocument(words=['get'], tags=[957]),
#  TaggedDocument(words=['connected'], tags=[958]),
#  TaggedDocument(words=['connected'], tags=[959]),
#  TaggedDocument(words=['built'], tags=[960]),
#  TaggedDocument(words=['quality'], tags=[961]),
#  TaggedDocument(words=['nice'], tags=[962]),
#  TaggedDocument(words=['soft'], tags=[963]),
#  TaggedDocument(words=['feel'], tags=[964]),
#  TaggedDocument(words=['good'], tags=[965]),
#  TaggedDocument(words=['material'], tags=[966]),
#  TaggedDocument(words=['quality'], tags=[967]),
#  TaggedDocument(words=['elegant'], tags=[968]),
#  TaggedDocument(words=['colour'], tags=[969]),
#  TaggedDocument(words=['combo'], tags=[970]),
#  TaggedDocument(words=['imperial'], tags=[971]),
#  TaggedDocument(words=['jade'], tags=[972]),
#  TaggedDocument(words=['less'], tags=[973]),
#  TaggedDocument(words=['weight'], tags=[974]),
#  TaggedDocument(words=['good'], tags=[975]),
#  TaggedDocument(words=['fit'], tags=[976]),
#  TaggedDocument(words=['ears'], tags=[977]),
#  TaggedDocument(words=['used'], tags=[978]),
#  TaggedDocument(words=['still'], tags=[979]),
#  TaggedDocument(words=['good'], tags=[980]),
#  TaggedDocument(words=['charge'], tags=[981]),
#  TaggedDocument(words=['connectivity'], tags=[982]),
#  TaggedDocument(words=['about'], tags=[983]),
#  TaggedDocument(words=['charge'], tags=[984]),
#  TaggedDocument(words=['review'], tags=[985]),
#  TaggedDocument(words=['week'], tags=[986]),
#  TaggedDocument(words=['while'], tags=[987]),
#  TaggedDocument(words=['connecting'], tags=[988]),
#  TaggedDocument(words=['mono'], tags=[989]),
#  TaggedDocument(words=['two'], tags=[990]),
#  TaggedDocument(words=['earbuds'], tags=[991]),
#  TaggedDocument(words=['connected'], tags=[992]),
#  TaggedDocument(words=['mobile'], tags=[993]),
#  TaggedDocument(words=['devices'], tags=[994]),
#  TaggedDocument(words=['like'], tags=[995]),
#  TaggedDocument(words=['bud'], tags=[996]),
#  TaggedDocument(words=['one'], tags=[997]),
#  TaggedDocument(words=['mobile'], tags=[998]),
#  TaggedDocument(words=['bud'], tags=[999]),
#  ...]

# %%
## Train doc2vec model
model = Doc2Vec(tagged_data, vector_size=20, window=2, min_count=1, workers=4, epochs = 100)
# Save trained doc2vec model
model.save("test_doc2vec.model")
## Load saved doc2vec model
model= Doc2Vec.load("test_doc2vec.model")
## Print model vocabulary
model.wv.vocab
# Out:
# {'poor': <gensim.models.keyedvectors.Vocab at 0x15447c03370>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x15447c038e0>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x15447c03970>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x15447c03490>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x15447c03940>,
#  'earphones': <gensim.models.keyedvectors.Vocab at 0x15447c03760>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x15447c03dc0>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x15447c03730>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x15447c03670>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x15447c037f0>,
#  'reviews': <gensim.models.keyedvectors.Vocab at 0x15447c03f70>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x15447c03e20>,
#  'mostly': <gensim.models.keyedvectors.Vocab at 0x15447c037c0>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x15447c03850>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x15447c03a60>,
#  'buds': <gensim.models.keyedvectors.Vocab at 0x15447c03880>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x15447c03a90>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x15447c03ee0>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x15447c03f40>,
#  'dual': <gensim.models.keyedvectors.Vocab at 0x15447c03c40>,
#  'drivers': <gensim.models.keyedvectors.Vocab at 0x15447c03e80>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x15447c03fa0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x15447c03610>,
#  'loud': <gensim.models.keyedvectors.Vocab at 0x15447c035e0>,
#  'output': <gensim.models.keyedvectors.Vocab at 0x15447c03d00>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x15447c03cd0>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x15447c03b50>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x15447c034c0>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x15447c036d0>,
#  'plastic': <gensim.models.keyedvectors.Vocab at 0x15447c036a0>,
#  'magnetic': <gensim.models.keyedvectors.Vocab at 0x15447c03b80>,
#  'snap': <gensim.models.keyedvectors.Vocab at 0x15447c03d30>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x15447c034f0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x15447c039a0>,
#  'complaints': <gensim.models.keyedvectors.Vocab at 0x15447c45070>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x15447c450d0>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x15447c45130>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x15447c45190>,
#  'miserably': <gensim.models.keyedvectors.Vocab at 0x15447c451f0>,
#  'microphone': <gensim.models.keyedvectors.Vocab at 0x15447c45250>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x15447c452b0>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x15447c45310>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x15447c45370>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x15447c453d0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x15447c45430>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x15447c45490>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x15447c454f0>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x15447c45550>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x15447c455b0>,
#  'suffer': <gensim.models.keyedvectors.Vocab at 0x15447c45610>,
#  'calls': <gensim.models.keyedvectors.Vocab at 0x15447c45670>,
#  'muffled': <gensim.models.keyedvectors.Vocab at 0x15447c456d0>,
#  'mics': <gensim.models.keyedvectors.Vocab at 0x15447c45730>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x15447c45790>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x15447c457f0>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x15447c45850>,
#  'regarding': <gensim.models.keyedvectors.Vocab at 0x15447c458b0>,
#  'quiet': <gensim.models.keyedvectors.Vocab at 0x15447c45910>,
#  'noisy': <gensim.models.keyedvectors.Vocab at 0x15447c45970>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x15447c459d0>,
#  'sounding': <gensim.models.keyedvectors.Vocab at 0x15447c45a30>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x15447c45a90>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x15447c45af0>,
#  'personally': <gensim.models.keyedvectors.Vocab at 0x15447c45b50>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x15447c45bb0>,
#  'pairing': <gensim.models.keyedvectors.Vocab at 0x15447c45c10>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x15447c45c70>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x15447c45cd0>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x15447c45d30>,
#  'microphones': <gensim.models.keyedvectors.Vocab at 0x15447c45d90>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x15447c45df0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x15447c45e50>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x15447c45eb0>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x15447c45f10>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x15447c45f70>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x15447c45fd0>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x15447c48070>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x15447c480d0>,
#  'passive': <gensim.models.keyedvectors.Vocab at 0x15447c48130>,
#  'noise': <gensim.models.keyedvectors.Vocab at 0x15447c48190>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x15447c481f0>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x15447c48250>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x15447c482b0>,
#  'vouches': <gensim.models.keyedvectors.Vocab at 0x15447c48310>,
#  'posting': <gensim.models.keyedvectors.Vocab at 0x15447c48370>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x15447c483d0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x15447c48430>,
#  'kidding': <gensim.models.keyedvectors.Vocab at 0x15447c48490>,
#  'crossbeats': <gensim.models.keyedvectors.Vocab at 0x15447c484f0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x15447c48550>,
#  'returned': <gensim.models.keyedvectors.Vocab at 0x15447c485b0>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x15447c48610>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x15447c48670>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x15447c486d0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x15447c48730>,
#  'competitors': <gensim.models.keyedvectors.Vocab at 0x15447c48790>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x15447c487f0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x15447c48850>,
#  'mic': <gensim.models.keyedvectors.Vocab at 0x15447c488b0>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x15447c48910>,
#  'sounds': <gensim.models.keyedvectors.Vocab at 0x15447c48970>,
#  'cancellation': <gensim.models.keyedvectors.Vocab at 0x15447c489d0>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x15447c48a30>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x15447c48a90>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x15447c48af0>,
#  'earpods': <gensim.models.keyedvectors.Vocab at 0x15447c48b50>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x15447c48bb0>,
#  'snug': <gensim.models.keyedvectors.Vocab at 0x15447c48c10>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x15447c48c70>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x15447c48cd0>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x15447c48d30>,
#  'wearing': <gensim.models.keyedvectors.Vocab at 0x15447c48d90>,
#  'exercise': <gensim.models.keyedvectors.Vocab at 0x15447c48df0>,
#  'whic': <gensim.models.keyedvectors.Vocab at 0x15447c48e50>,
#  'includes': <gensim.models.keyedvectors.Vocab at 0x15447c48eb0>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x15447c48f10>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x15447c48f70>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x15447c48fd0>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x15447c4e070>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x15447c4e0d0>,
#  'skeptical': <gensim.models.keyedvectors.Vocab at 0x15447c4e130>,
#  'buying': <gensim.models.keyedvectors.Vocab at 0x15447c4e190>,
#  'performing': <gensim.models.keyedvectors.Vocab at 0x15447c4e1f0>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x15447c4e250>,
#  'expectations': <gensim.models.keyedvectors.Vocab at 0x15447c4e2b0>,
#  'sleek': <gensim.models.keyedvectors.Vocab at 0x15447c4e310>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x15447c4e370>,
#  'audio': <gensim.models.keyedvectors.Vocab at 0x15447c4e3d0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x15447c4e430>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x15447c4e490>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x15447c4e4f0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x15447c4e550>,
#  'hi': <gensim.models.keyedvectors.Vocab at 0x15447c4e5b0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x15447c4e610>,
#  'earbuds': <gensim.models.keyedvectors.Vocab at 0x15447c4e670>,
#  'rs': <gensim.models.keyedvectors.Vocab at 0x15447c4e6d0>,
#  'feels': <gensim.models.keyedvectors.Vocab at 0x15447c4e730>,
#  'soo': <gensim.models.keyedvectors.Vocab at 0x15447c4e790>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x15447c4e7f0>,
#  'bass': <gensim.models.keyedvectors.Vocab at 0x15447c4e850>,
#  'punchy': <gensim.models.keyedvectors.Vocab at 0x15447c4e8b0>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x15447c4e910>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x15447c4e970>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x15447c4e9d0>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x15447c4ea30>,
#  'ur': <gensim.models.keyedvectors.Vocab at 0x15447c4ea90>,
#  'budget': <gensim.models.keyedvectors.Vocab at 0x15447c4eaf0>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x15447c4eb50>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x15447c4ebb0>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x15447c4ec10>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x15447c4ec70>,
#  'pathetic': <gensim.models.keyedvectors.Vocab at 0x15447c4ecd0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x15447c4ed30>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x15447c4ed90>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x15447c4edf0>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x15447c4ee50>,
#  'tilted': <gensim.models.keyedvectors.Vocab at 0x15447c4eeb0>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x15447c4ef10>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x15447c4ef70>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x15447c4efd0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x15447c53070>,
#  'straight': <gensim.models.keyedvectors.Vocab at 0x15447c530d0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x15447c53130>,
#  'stops': <gensim.models.keyedvectors.Vocab at 0x15447c53190>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x15447c531f0>,
#  'frustrating': <gensim.models.keyedvectors.Vocab at 0x15447c53250>,
#  'utter': <gensim.models.keyedvectors.Vocab at 0x15447c532b0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x15447c53310>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x15447c53370>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x15447c533d0>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x15447c53430>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x15447c53490>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x15447c534f0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x15447c53550>,
#  'proper': <gensim.models.keyedvectors.Vocab at 0x15447c535b0>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x15447c53610>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x15447c53670>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x15447c536d0>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x15447c53730>,
#  'cheap': <gensim.models.keyedvectors.Vocab at 0x15447c53790>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x15447c537f0>,
#  'cranky': <gensim.models.keyedvectors.Vocab at 0x15447c53850>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x15447c538b0>,
#  'buttons': <gensim.models.keyedvectors.Vocab at 0x15447c53910>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x15447c53970>,
#  'track': <gensim.models.keyedvectors.Vocab at 0x15447c539d0>,
#  'fits': <gensim.models.keyedvectors.Vocab at 0x15447c53a30>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x15447c53a90>,
#  'ears': <gensim.models.keyedvectors.Vocab at 0x15447c53af0>,
#  'rubber': <gensim.models.keyedvectors.Vocab at 0x15447c53b50>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x15447c53bb0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x15447c53c10>,
#  'treble': <gensim.models.keyedvectors.Vocab at 0x15447c53c70>,
#  'hurts': <gensim.models.keyedvectors.Vocab at 0x15447c53cd0>,
#  'ordinary': <gensim.models.keyedvectors.Vocab at 0x15447c53d30>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x15447c53d90>,
#  'purchased': <gensim.models.keyedvectors.Vocab at 0x15447c53df0>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x15447c53e50>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x15447c53eb0>,
#  'min': <gensim.models.keyedvectors.Vocab at 0x15447c53f10>,
#  'wondered': <gensim.models.keyedvectors.Vocab at 0x15447c53f70>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x15447c53fd0>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x15447c59070>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x15447c590d0>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x15447c59130>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x15447c59190>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x15447c591f0>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x15447c59250>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x15447c592b0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x15447c59310>,
#  'ear': <gensim.models.keyedvectors.Vocab at 0x15447c59370>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x15447c593d0>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x15447c59430>,
#  'scores': <gensim.models.keyedvectors.Vocab at 0x15447c59490>,
#  'zero': <gensim.models.keyedvectors.Vocab at 0x15447c594f0>,
#  'workout': <gensim.models.keyedvectors.Vocab at 0x15447c59550>,
#  'falls': <gensim.models.keyedvectors.Vocab at 0x15447c595b0>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x15447c59610>,
#  'pairs': <gensim.models.keyedvectors.Vocab at 0x15447c59670>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x15447c596d0>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x15447c59730>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x15447c59790>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x15447c597f0>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x15447c59850>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x15447c598b0>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x15447c59910>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x15447c59970>,
#  'sticks': <gensim.models.keyedvectors.Vocab at 0x15447c599d0>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x15447c59a30>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x15447c59a90>,
#  'pictures': <gensim.models.keyedvectors.Vocab at 0x15447c59af0>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x15447c59b50>,
#  'visible': <gensim.models.keyedvectors.Vocab at 0x15447c59bb0>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x15447c59c10>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x15447c59c70>,
#  'listento': <gensim.models.keyedvectors.Vocab at 0x15447c59cd0>,
#  'crisp': <gensim.models.keyedvectors.Vocab at 0x15447c59d30>,
#  'bluetooth': <gensim.models.keyedvectors.Vocab at 0x15447c59d90>,
#  'auto': <gensim.models.keyedvectors.Vocab at 0x15447c59df0>,
#  'connects': <gensim.models.keyedvectors.Vocab at 0x15447c59e50>,
#  'earphone': <gensim.models.keyedvectors.Vocab at 0x15447c59eb0>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x15447c59f10>,
#  'options': <gensim.models.keyedvectors.Vocab at 0x15447c59f70>,
#  'brands': <gensim.models.keyedvectors.Vocab at 0x15447c59fd0>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x15447c5e070>,
#  'deadline': <gensim.models.keyedvectors.Vocab at 0x15447c5e0d0>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x15447c5e130>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x15447c5e190>,
#  'alright': <gensim.models.keyedvectors.Vocab at 0x15447c5e1f0>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x15447c5e250>,
#  'finicky': <gensim.models.keyedvectors.Vocab at 0x15447c5e2b0>,
#  'pros': <gensim.models.keyedvectors.Vocab at 0x15447c5e310>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x15447c5e370>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x15447c5e3d0>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x15447c5e430>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x15447c5e490>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x15447c5e4f0>,
#  'button': <gensim.models.keyedvectors.Vocab at 0x15447c5e550>,
#  'controls': <gensim.models.keyedvectors.Vocab at 0x15447c5e5b0>,
#  'battery': <gensim.models.keyedvectors.Vocab at 0x15447c5e610>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x15447c5e670>,
#  'adequate': <gensim.models.keyedvectors.Vocab at 0x15447c5e6d0>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x15447c5e730>,
#  'userscons': <gensim.models.keyedvectors.Vocab at 0x15447c5e790>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x15447c5e7f0>,
#  'specially': <gensim.models.keyedvectors.Vocab at 0x15447c5e850>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x15447c5e8b0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x15447c5e910>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x15447c5e970>,
#  'badit': <gensim.models.keyedvectors.Vocab at 0x15447c5e9d0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x15447c5ea30>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x15447c5ea90>,
#  'overpriced': <gensim.models.keyedvectors.Vocab at 0x15447c5eaf0>,
#  'bang': <gensim.models.keyedvectors.Vocab at 0x15447c5eb50>,
#  'buck': <gensim.models.keyedvectors.Vocab at 0x15447c5ebb0>,
#  'wireless': <gensim.models.keyedvectors.Vocab at 0x15447c5ec10>,
#  'marvel': <gensim.models.keyedvectors.Vocab at 0x15447c5ec70>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x15447c5ecd0>,
#  'praised': <gensim.models.keyedvectors.Vocab at 0x15447c5ed30>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x15447c5ed90>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x15447c5edf0>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x15447c5ee50>,
#  'adorable': <gensim.models.keyedvectors.Vocab at 0x15447c5eeb0>,
#  'pieces': <gensim.models.keyedvectors.Vocab at 0x15447c5ef10>,
#  'pair': <gensim.models.keyedvectors.Vocab at 0x15447c5ef70>,
#  'amazingly': <gensim.models.keyedvectors.Vocab at 0x15447c5efd0>,
#  'quickly': <gensim.models.keyedvectors.Vocab at 0x15447c63070>,
#  'tab': <gensim.models.keyedvectors.Vocab at 0x15447c630d0>,
#  'bt': <gensim.models.keyedvectors.Vocab at 0x15447c63130>,
#  'stunning': <gensim.models.keyedvectors.Vocab at 0x15447c63190>,
#  'levels': <gensim.models.keyedvectors.Vocab at 0x15447c631f0>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x15447c63220>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x15447c632b0>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x15447c63310>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x15447c63370>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x15447c633d0>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x15447c63430>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x15447c63490>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x15447c634f0>,
#  'tone': <gensim.models.keyedvectors.Vocab at 0x15447c63550>,
#  'mushy': <gensim.models.keyedvectors.Vocab at 0x15447c635b0>,
#  'hehe': <gensim.models.keyedvectors.Vocab at 0x15447c63610>,
#  'latency': <gensim.models.keyedvectors.Vocab at 0x15447c63670>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x15447c636d0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x15447c63730>,
#  'viewing': <gensim.models.keyedvectors.Vocab at 0x15447c63790>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x15447c637f0>,
#  'lag': <gensim.models.keyedvectors.Vocab at 0x15447c63850>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x15447c638b0>,
#  'charge': <gensim.models.keyedvectors.Vocab at 0x15447c63910>,
#  'cute': <gensim.models.keyedvectors.Vocab at 0x15447c63970>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x15447c639d0>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x15447c63a30>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x15447c63a90>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x15447c63af0>,
#  'pocket': <gensim.models.keyedvectors.Vocab at 0x15447c63b50>,
#  'sturdy': <gensim.models.keyedvectors.Vocab at 0x15447c63bb0>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x15447c63c10>,
#  'portable': <gensim.models.keyedvectors.Vocab at 0x15447c63c70>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x15447c63cd0>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x15447c63d30>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x15447c63d90>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x15447c63df0>,
#  'grreat': <gensim.models.keyedvectors.Vocab at 0x15447c63e50>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x15447c63eb0>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x15447c63f10>,
#  'charging': <gensim.models.keyedvectors.Vocab at 0x15447c63f70>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x15447c63fd0>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x15447c69070>,
#  'charger': <gensim.models.keyedvectors.Vocab at 0x15447c690d0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x15447c69130>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x15447c69190>,
#  'paid': <gensim.models.keyedvectors.Vocab at 0x15447c691f0>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x15447c69250>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x15447c692b0>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x15447c69310>,
#  'incentive': <gensim.models.keyedvectors.Vocab at 0x15447c69370>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x15447c693d0>,
#  'ganna': <gensim.models.keyedvectors.Vocab at 0x15447c69430>,
#  'subscription': <gensim.models.keyedvectors.Vocab at 0x15447c69490>,
#  'register': <gensim.models.keyedvectors.Vocab at 0x15447c694f0>,
#  'warranty': <gensim.models.keyedvectors.Vocab at 0x15447c69550>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x15447c695b0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x15447c69610>,
#  'whatsapp': <gensim.models.keyedvectors.Vocab at 0x15447c69670>,
#  'messages': <gensim.models.keyedvectors.Vocab at 0x15447c696d0>,
#  'customer': <gensim.models.keyedvectors.Vocab at 0x15447c69730>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x15447c69790>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x15447c697f0>,
#  'continuously': <gensim.models.keyedvectors.Vocab at 0x15447c69850>,
#  'asking': <gensim.models.keyedvectors.Vocab at 0x15447c698b0>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x15447c69910>,
#  'screenshot': <gensim.models.keyedvectors.Vocab at 0x15447c69970>,
#  'exchange': <gensim.models.keyedvectors.Vocab at 0x15447c699d0>,
#  'gaana': <gensim.models.keyedvectors.Vocab at 0x15447c69a30>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x15447c69a90>,
#  'dedicated': <gensim.models.keyedvectors.Vocab at 0x15447c69af0>,
#  'channel': <gensim.models.keyedvectors.Vocab at 0x15447c69b50>,
#  'pushing': <gensim.models.keyedvectors.Vocab at 0x15447c69bb0>,
#  'customers': <gensim.models.keyedvectors.Vocab at 0x15447c69c10>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x15447c69c70>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x15447c69cd0>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x15447c69d30>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x15447c69d90>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x15447c69df0>,
#  'resolve': <gensim.models.keyedvectors.Vocab at 0x15447c69e50>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x15447c69eb0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x15447c69f10>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x15447c69f70>,
#  'reply': <gensim.models.keyedvectors.Vocab at 0x15447c69fd0>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x15447c6e070>,
#  'invoice': <gensim.models.keyedvectors.Vocab at 0x15447c6e0d0>,
#  'details': <gensim.models.keyedvectors.Vocab at 0x15447c6e130>,
#  'sending': <gensim.models.keyedvectors.Vocab at 0x15447c6e190>,
#  'id': <gensim.models.keyedvectors.Vocab at 0x15447c6e1f0>,
#  'registered': <gensim.models.keyedvectors.Vocab at 0x15447c6e250>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x15447c6e2b0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x15447c6e310>,
#  'restart': <gensim.models.keyedvectors.Vocab at 0x15447c6e370>,
#  'bud': <gensim.models.keyedvectors.Vocab at 0x15447c6e3d0>,
#  'resolves': <gensim.models.keyedvectors.Vocab at 0x15447c6e430>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x15447c6e490>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x15447c6e4f0>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x15447c6e550>,
#  'facing': <gensim.models.keyedvectors.Vocab at 0x15447c6e5b0>,
#  'connectivity': <gensim.models.keyedvectors.Vocab at 0x15447c6e610>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x15447c6e670>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x15447c6e6d0>,
#  'till': <gensim.models.keyedvectors.Vocab at 0x15447c6e730>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x15447c6e790>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x15447c6e7f0>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x15447c6e850>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x15447c6e8b0>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x15447c6e910>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x15447c6e970>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x15447c6e9d0>,
#  'disrupted': <gensim.models.keyedvectors.Vocab at 0x15447c6ea30>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x15447c6ea90>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x15447c6eaf0>,
#  'seconds': <gensim.models.keyedvectors.Vocab at 0x15447c6eb50>,
#  'repeating': <gensim.models.keyedvectors.Vocab at 0x15447c6ebb0>,
#  'irritating': <gensim.models.keyedvectors.Vocab at 0x15447c6ec10>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x15447c6ec70>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x15447c6ecd0>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x15447c6ed30>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x15447c6ed90>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x15447c6edf0>,
#  'powered': <gensim.models.keyedvectors.Vocab at 0x15447c6ee50>,
#  'devices': <gensim.models.keyedvectors.Vocab at 0x15447c6eeb0>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x15447c6ef10>,
#  'wifi': <gensim.models.keyedvectors.Vocab at 0x15447c6ef70>,
#  'connection': <gensim.models.keyedvectors.Vocab at 0x15447c6efd0>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x15448604070>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x154486040d0>,
#  'replied': <gensim.models.keyedvectors.Vocab at 0x15448604130>,
#  'speaker': <gensim.models.keyedvectors.Vocab at 0x15448604190>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x154486041f0>,
#  'faced': <gensim.models.keyedvectors.Vocab at 0x15448604250>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x154486042b0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x15448604310>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x15448604370>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x154486043d0>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x15448604430>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x15448604490>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x154486044f0>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x15448604550>,
#  'replacement': <gensim.models.keyedvectors.Vocab at 0x154486045b0>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x15448604610>,
#  'reminder': <gensim.models.keyedvectors.Vocab at 0x15448604670>,
#  'everyday': <gensim.models.keyedvectors.Vocab at 0x154486046d0>,
#  'alternate': <gensim.models.keyedvectors.Vocab at 0x15448604730>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x15448604790>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x154486047f0>,
#  'offits': <gensim.models.keyedvectors.Vocab at 0x15448604850>,
#  'jus': <gensim.models.keyedvectors.Vocab at 0x154486048b0>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x15448604910>,
#  'headphone': <gensim.models.keyedvectors.Vocab at 0x15448604970>,
#  'functionality': <gensim.models.keyedvectors.Vocab at 0x154486049d0>,
#  'problemsi': <gensim.models.keyedvectors.Vocab at 0x15448604a30>,
#  'regret': <gensim.models.keyedvectors.Vocab at 0x15448604a90>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x15448604af0>,
#  'itnoise': <gensim.models.keyedvectors.Vocab at 0x15448604b50>,
#  'crappy': <gensim.models.keyedvectors.Vocab at 0x15448604bb0>,
#  'andvoice': <gensim.models.keyedvectors.Vocab at 0x15448604c10>,
#  'echo': <gensim.models.keyedvectors.Vocab at 0x15448604c70>,
#  'sorts': <gensim.models.keyedvectors.Vocab at 0x15448604cd0>,
#  'callsand': <gensim.models.keyedvectors.Vocab at 0x15448604d30>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x15448604d90>,
#  'handy': <gensim.models.keyedvectors.Vocab at 0x15448604df0>,
#  'device': <gensim.models.keyedvectors.Vocab at 0x15448604e20>,
#  'slick': <gensim.models.keyedvectors.Vocab at 0x15448604eb0>,
#  'reset': <gensim.models.keyedvectors.Vocab at 0x15448604f10>,
#  'guide': <gensim.models.keyedvectors.Vocab at 0x15448604f70>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x15448604fd0>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x1544860a070>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x1544860a0d0>,
#  'receiving': <gensim.models.keyedvectors.Vocab at 0x1544860a130>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1544860a190>,
#  'connecting': <gensim.models.keyedvectors.Vocab at 0x1544860a1f0>,
#  'fails': <gensim.models.keyedvectors.Vocab at 0x1544860a250>,
#  'detect': <gensim.models.keyedvectors.Vocab at 0x1544860a2b0>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x1544860a310>,
#  'compare': <gensim.models.keyedvectors.Vocab at 0x1544860a370>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x1544860a3d0>,
#  'services': <gensim.models.keyedvectors.Vocab at 0x1544860a430>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x1544860a490>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x1544860a4f0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1544860a550>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x1544860a5b0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1544860a610>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x1544860a670>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x1544860a6d0>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x1544860a730>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x1544860a790>,
#  'startup': <gensim.models.keyedvectors.Vocab at 0x1544860a7f0>,
#  'chic': <gensim.models.keyedvectors.Vocab at 0x1544860a850>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x1544860a8b0>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1544860a910>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x1544860a970>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x1544860a9d0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x1544860aa30>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x1544860aa90>,
#  'kinda': <gensim.models.keyedvectors.Vocab at 0x1544860aaf0>,
#  'pressed': <gensim.models.keyedvectors.Vocab at 0x1544860ab50>,
#  'earverdict': <gensim.models.keyedvectors.Vocab at 0x1544860abb0>,
#  'cheated': <gensim.models.keyedvectors.Vocab at 0x1544860ac10>,
#  'fake': <gensim.models.keyedvectors.Vocab at 0x1544860ac70>,
#  'youtubers': <gensim.models.keyedvectors.Vocab at 0x1544860acd0>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x1544860ad30>,
#  'jock': <gensim.models.keyedvectors.Vocab at 0x1544860ad90>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x1544860adf0>,
#  'listening': <gensim.models.keyedvectors.Vocab at 0x1544860ae50>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x1544860aeb0>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x1544860af10>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x1544860af70>,
#  'understood': <gensim.models.keyedvectors.Vocab at 0x1544860afd0>,
#  'promote': <gensim.models.keyedvectors.Vocab at 0x1544860e070>,
#  'chinese': <gensim.models.keyedvectors.Vocab at 0x1544860e0d0>,
#  'wired': <gensim.models.keyedvectors.Vocab at 0x1544860e130>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x1544860e190>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x1544860e1f0>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x1544860e250>,
#  'biased': <gensim.models.keyedvectors.Vocab at 0x1544860e2b0>,
#  'infact': <gensim.models.keyedvectors.Vocab at 0x1544860e310>,
#  'garbage': <gensim.models.keyedvectors.Vocab at 0x1544860e370>,
#  'plasticy': <gensim.models.keyedvectors.Vocab at 0x1544860e3d0>,
#  'delicate': <gensim.models.keyedvectors.Vocab at 0x1544860e430>,
#  'properly': <gensim.models.keyedvectors.Vocab at 0x1544860e490>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x1544860e4f0>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x1544860e550>,
#  'tws': <gensim.models.keyedvectors.Vocab at 0x1544860e5b0>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x1544860e610>,
#  'swift': <gensim.models.keyedvectors.Vocab at 0x1544860e670>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x1544860e6d0>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x1544860e730>,
#  'connected': <gensim.models.keyedvectors.Vocab at 0x1544860e790>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x1544860e7f0>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x1544860e850>,
#  'elegant': <gensim.models.keyedvectors.Vocab at 0x1544860e8b0>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x1544860e910>,
#  'combo': <gensim.models.keyedvectors.Vocab at 0x1544860e970>,
#  'imperial': <gensim.models.keyedvectors.Vocab at 0x1544860e9d0>,
#  'jade': <gensim.models.keyedvectors.Vocab at 0x1544860ea30>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x1544860ea90>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x1544860eaf0>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x1544860eb50>,
#  'mono': <gensim.models.keyedvectors.Vocab at 0x1544860ebb0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1544860ec10>,
#  'mobile': <gensim.models.keyedvectors.Vocab at 0x1544860ec70>,
#  'reconnecting': <gensim.models.keyedvectors.Vocab at 0x1544860ecd0>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x1544860ed30>,
#  'moving': <gensim.models.keyedvectors.Vocab at 0x1544860ed90>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1544860edf0>,
#  'rooms': <gensim.models.keyedvectors.Vocab at 0x1544860ee50>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x1544860eeb0>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x1544860ef10>,
#  'magnets': <gensim.models.keyedvectors.Vocab at 0x1544860ef70>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x1544860efd0>,
#  'audiophile': <gensim.models.keyedvectors.Vocab at 0x15448614070>,
#  'separation': <gensim.models.keyedvectors.Vocab at 0x154486140d0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x15448614130>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x15448614190>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x154486141f0>,
#  'solved': <gensim.models.keyedvectors.Vocab at 0x15448614250>,
#  'superb': <gensim.models.keyedvectors.Vocab at 0x154486142b0>,
#  'dominate': <gensim.models.keyedvectors.Vocab at 0x15448614310>,
#  'vocals': <gensim.models.keyedvectors.Vocab at 0x15448614370>,
#  'fairly': <gensim.models.keyedvectors.Vocab at 0x154486143d0>,
#  'balanced': <gensim.models.keyedvectors.Vocab at 0x15448614430>,
#  'performs': <gensim.models.keyedvectors.Vocab at 0x15448614490>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x154486144f0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x15448614550>,
#  'slightly': <gensim.models.keyedvectors.Vocab at 0x154486145b0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x15448614610>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x15448614670>,
#  'bend': <gensim.models.keyedvectors.Vocab at 0x154486146d0>,
#  'horizontally': <gensim.models.keyedvectors.Vocab at 0x15448614730>,
#  'upside': <gensim.models.keyedvectors.Vocab at 0x15448614790>,
#  'downthe': <gensim.models.keyedvectors.Vocab at 0x154486147f0>,
#  'proof': <gensim.models.keyedvectors.Vocab at 0x15448614850>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x154486148b0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x15448614910>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x15448614970>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x154486149d0>,
#  'exterior': <gensim.models.keyedvectors.Vocab at 0x15448614a30>,
#  'creep': <gensim.models.keyedvectors.Vocab at 0x15448614a90>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x15448614af0>,
#  'moviethe': <gensim.models.keyedvectors.Vocab at 0x15448614b50>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x15448614bb0>,
#  'wear': <gensim.models.keyedvectors.Vocab at 0x15448614c10>,
#  'announce': <gensim.models.keyedvectors.Vocab at 0x15448614c70>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x15448614cd0>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x15448614d30>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x15448614d90>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x15448614df0>,
#  'copper': <gensim.models.keyedvectors.Vocab at 0x15448614e50>,
#  'sexy': <gensim.models.keyedvectors.Vocab at 0x15448614eb0>,
#  'af': <gensim.models.keyedvectors.Vocab at 0x15448614f10>,
#  'disappoint': <gensim.models.keyedvectors.Vocab at 0x15448614f70>,
#  'therego': <gensim.models.keyedvectors.Vocab at 0x15448614fd0>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x15448619070>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x154486190d0>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x15448619130>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x15448619190>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x154486191f0>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x15448619250>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x154486192b0>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x15448619310>,
#  'misleading': <gensim.models.keyedvectors.Vocab at 0x15448619370>,
#  'dishonest': <gensim.models.keyedvectors.Vocab at 0x154486193d0>,
#  'disappointing': <gensim.models.keyedvectors.Vocab at 0x15448619430>,
#  'hopes': <gensim.models.keyedvectors.Vocab at 0x15448619490>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x154486194f0>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x15448619550>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x154486195b0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x15448619610>,
#  'mistake': <gensim.models.keyedvectors.Vocab at 0x15448619670>,
#  'disappointed': <gensim.models.keyedvectors.Vocab at 0x154486196d0>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x15448619730>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x15448619790>,
#  'fixes': <gensim.models.keyedvectors.Vocab at 0x154486197f0>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x15448619850>,
#  'laptop': <gensim.models.keyedvectors.Vocab at 0x154486198b0>,
#  'audible': <gensim.models.keyedvectors.Vocab at 0x15448619910>,
#  'experienced': <gensim.models.keyedvectors.Vocab at 0x15448619970>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x154486199d0>,
#  'decreasing': <gensim.models.keyedvectors.Vocab at 0x15448619a60>,
#  'volume': <gensim.models.keyedvectors.Vocab at 0x15448619a90>,
#  'sensor': <gensim.models.keyedvectors.Vocab at 0x15448619af0>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x15448619b50>,
#  'rhythm': <gensim.models.keyedvectors.Vocab at 0x15448619bb0>,
#  'taps': <gensim.models.keyedvectors.Vocab at 0x15448619c10>,
#  'waited': <gensim.models.keyedvectors.Vocab at 0x15448619c70>,
#  'sometime': <gensim.models.keyedvectors.Vocab at 0x15448619cd0>,
#  'practicing': <gensim.models.keyedvectors.Vocab at 0x15448619d30>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x15448619d90>,
#  'worse': <gensim.models.keyedvectors.Vocab at 0x15448619df0>,
#  'brutally': <gensim.models.keyedvectors.Vocab at 0x15448619e50>,
#  'charged': <gensim.models.keyedvectors.Vocab at 0x15448619eb0>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x15448619f10>,
#  'approx': <gensim.models.keyedvectors.Vocab at 0x15448619f70>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x15448619fd0>,
#  'boat': <gensim.models.keyedvectors.Vocab at 0x1544861f070>,
#  'rockerz': <gensim.models.keyedvectors.Vocab at 0x1544861f0d0>,
#  'neckband': <gensim.models.keyedvectors.Vocab at 0x1544861f130>,
#  'costed': <gensim.models.keyedvectors.Vocab at 0x1544861f190>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1544861f1f0>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x1544861f250>,
#  'spending': <gensim.models.keyedvectors.Vocab at 0x1544861f2b0>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x1544861f310>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x1544861f370>,
#  'robust': <gensim.models.keyedvectors.Vocab at 0x1544861f3d0>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x1544861f430>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x1544861f490>,
#  'opened': <gensim.models.keyedvectors.Vocab at 0x1544861f4f0>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x1544861f550>,
#  'immediately': <gensim.models.keyedvectors.Vocab at 0x1544861f5b0>,
#  'liked': <gensim.models.keyedvectors.Vocab at 0x1544861f610>,
#  'durable': <gensim.models.keyedvectors.Vocab at 0x1544861f670>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x1544861f6d0>,
#  'fallen': <gensim.models.keyedvectors.Vocab at 0x1544861f730>,
#  'wo': <gensim.models.keyedvectors.Vocab at 0x1544861f790>,
#  'cancelling': <gensim.models.keyedvectors.Vocab at 0x1544861f7f0>,
#  'traffic': <gensim.models.keyedvectors.Vocab at 0x1544861f850>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x1544861f8b0>,
#  'feature': <gensim.models.keyedvectors.Vocab at 0x1544861f910>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x1544861f970>,
#  'caller': <gensim.models.keyedvectors.Vocab at 0x1544861f9d0>,
#  'certify': <gensim.models.keyedvectors.Vocab at 0x1544861fa30>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x1544861fa90>,
#  'overcome': <gensim.models.keyedvectors.Vocab at 0x1544861faf0>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x1544861fb50>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x1544861fbb0>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x1544861fc10>,
#  'losing': <gensim.models.keyedvectors.Vocab at 0x1544861fc70>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x1544861fcd0>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x1544861fd30>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x1544861fd90>,
#  'educated': <gensim.models.keyedvectors.Vocab at 0x1544861fdf0>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x1544861fe50>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x1544861feb0>,
#  'placing': <gensim.models.keyedvectors.Vocab at 0x1544861ff10>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x1544861ff70>,
#  'mastered': <gensim.models.keyedvectors.Vocab at 0x1544861ffd0>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x15448625070>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x154486250d0>,
#  'airpods': <gensim.models.keyedvectors.Vocab at 0x15448625130>,
#  'initial': <gensim.models.keyedvectors.Vocab at 0x15448625190>,
#  'impressions': <gensim.models.keyedvectors.Vocab at 0x154486251f0>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x15448625250>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x154486252b0>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x15448625310>,
#  'clarity': <gensim.models.keyedvectors.Vocab at 0x15448625370>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x154486253d0>,
#  'soooo': <gensim.models.keyedvectors.Vocab at 0x15448625430>,
#  'rubbery': <gensim.models.keyedvectors.Vocab at 0x15448625490>,
#  'choosed': <gensim.models.keyedvectors.Vocab at 0x154486254f0>,
#  'fantastic': <gensim.models.keyedvectors.Vocab at 0x15448625550>,
#  'images': <gensim.models.keyedvectors.Vocab at 0x154486255b0>,
#  'attached': <gensim.models.keyedvectors.Vocab at 0x15448625610>,
#  'depends': <gensim.models.keyedvectors.Vocab at 0x15448625670>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x154486256d0>,
#  'provided': <gensim.models.keyedvectors.Vocab at 0x15448625730>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x15448625790>,
#  'coloured': <gensim.models.keyedvectors.Vocab at 0x154486257f0>,
#  'shades': <gensim.models.keyedvectors.Vocab at 0x15448625850>,
#  'produces': <gensim.models.keyedvectors.Vocab at 0x154486258b0>,
#  'clicked': <gensim.models.keyedvectors.Vocab at 0x15448625910>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x15448625970>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x154486259d0>,
#  'noicy': <gensim.models.keyedvectors.Vocab at 0x15448625a30>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x15448625a90>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x15448625af0>,
#  'watched': <gensim.models.keyedvectors.Vocab at 0x15448625b50>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x15448625bb0>,
#  'enjoyed': <gensim.models.keyedvectors.Vocab at 0x15448625c10>,
#  'rated': <gensim.models.keyedvectors.Vocab at 0x15448625c70>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x15448625cd0>,
#  'blupunkt': <gensim.models.keyedvectors.Vocab at 0x15448625d30>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x15448625d90>,
#  'awasome': <gensim.models.keyedvectors.Vocab at 0x15448625df0>,
#  'appeciating': <gensim.models.keyedvectors.Vocab at 0x15448625e50>,
#  'segment': <gensim.models.keyedvectors.Vocab at 0x15448625eb0>,
#  'screen': <gensim.models.keyedvectors.Vocab at 0x15448625f10>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x15448625f70>,
#  'neither': <gensim.models.keyedvectors.Vocab at 0x15448625fd0>,
#  'hd': <gensim.models.keyedvectors.Vocab at 0x1544862a070>,
#  'automatically': <gensim.models.keyedvectors.Vocab at 0x1544862a0d0>,
#  'disconnected': <gensim.models.keyedvectors.Vocab at 0x1544862a130>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x1544862a190>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1544862a1f0>,
#  'backup': <gensim.models.keyedvectors.Vocab at 0x1544862a250>,
#  'setup': <gensim.models.keyedvectors.Vocab at 0x1544862a2b0>,
#  'pod': <gensim.models.keyedvectors.Vocab at 0x1544862a310>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x1544862a370>,
#  'feeli': <gensim.models.keyedvectors.Vocab at 0x1544862a3d0>,
#  'classy': <gensim.models.keyedvectors.Vocab at 0x1544862a430>,
#  'mat': <gensim.models.keyedvectors.Vocab at 0x1544862a490>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x1544862a4f0>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x1544862a550>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x1544862a5b0>,
#  'grip': <gensim.models.keyedvectors.Vocab at 0x1544862a610>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1544862a670>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x1544862a6d0>,
#  'soundsound': <gensim.models.keyedvectors.Vocab at 0x1544862a730>,
#  'moderate': <gensim.models.keyedvectors.Vocab at 0x1544862a790>,
#  'lacks': <gensim.models.keyedvectors.Vocab at 0x1544862a7f0>,
#  'kicks': <gensim.models.keyedvectors.Vocab at 0x1544862a850>,
#  'punch': <gensim.models.keyedvectors.Vocab at 0x1544862a8b0>,
#  'recommended': <gensim.models.keyedvectors.Vocab at 0x1544862a910>,
#  'comfortnot': <gensim.models.keyedvectors.Vocab at 0x1544862a970>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1544862a9d0>,
#  'curvy': <gensim.models.keyedvectors.Vocab at 0x1544862aa30>,
#  'hai': <gensim.models.keyedvectors.Vocab at 0x1544862aa90>,
#  'bulky': <gensim.models.keyedvectors.Vocab at 0x1544862aaf0>,
#  'wings': <gensim.models.keyedvectors.Vocab at 0x1544862ab50>,
#  'stays': <gensim.models.keyedvectors.Vocab at 0x1544862abb0>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x1544862ac10>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1544862ac70>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x1544862acd0>,
#  'batteryhigh': <gensim.models.keyedvectors.Vocab at 0x1544862ad30>,
#  'battter': <gensim.models.keyedvectors.Vocab at 0x1544862ad90>,
#  'callingthis': <gensim.models.keyedvectors.Vocab at 0x1544862adf0>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x1544862ae50>,
#  'twh': <gensim.models.keyedvectors.Vocab at 0x1544862aeb0>,
#  'lags': <gensim.models.keyedvectors.Vocab at 0x1544862af10>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x1544862af70>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x1544862afd0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1544862f070>,
#  'pressing': <gensim.models.keyedvectors.Vocab at 0x1544862f0d0>,
# ...
#  'double': <gensim.models.keyedvectors.Vocab at 0x1544862f1f0>,
#  'loving': <gensim.models.keyedvectors.Vocab at 0x1544862f250>,
#  'atleast': <gensim.models.keyedvectors.Vocab at 0x1544862f2b0>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x1544862f310>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x1544862f370>,
#  'february': <gensim.models.keyedvectors.Vocab at 0x1544862f3d0>,
#  'july': <gensim.models.keyedvectors.Vocab at 0x1544862f430>,
#  'raised': <gensim.models.keyedvectors.Vocab at 0x1544862f490>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x1544862f4f0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x1544862f550>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x1544862f5b0>,
#  'packing': <gensim.models.keyedvectors.Vocab at 0x1544862f640>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x1544862f670>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x1544862f6d0>,
#  'observations': <gensim.models.keyedvectors.Vocab at 0x1544862f730>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x1544862f790>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x1544862f7f0>,
#  'warming': <gensim.models.keyedvectors.Vocab at 0x1544862f850>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x1544862f8b0>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1544862f910>,
#  'awesomely': <gensim.models.keyedvectors.Vocab at 0x1544862f970>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x1544862f9d0>,
#  'fell': <gensim.models.keyedvectors.Vocab at 0x1544862fa30>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x1544862fa90>,
#  'mids': <gensim.models.keyedvectors.Vocab at 0x1544862faf0>,
#  'lows': <gensim.models.keyedvectors.Vocab at 0x1544862fb50>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x1544862fbb0>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x1544862fc10>,
#  'songs': <gensim.models.keyedvectors.Vocab at 0x1544862fc70>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1544862fcd0>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1544862fd30>,
#  'atif': <gensim.models.keyedvectors.Vocab at 0x1544862fd90>,
#  'aslam': <gensim.models.keyedvectors.Vocab at 0x1544862fdf0>,
#  'singing': <gensim.models.keyedvectors.Vocab at 0x1544862fe50>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1544862feb0>,
#  'concert': <gensim.models.keyedvectors.Vocab at 0x1544862ff10>,
#  'recording': <gensim.models.keyedvectors.Vocab at 0x1544862ff70>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x1544862ffd0>,
#  'played': <gensim.models.keyedvectors.Vocab at 0x15448635070>,
#  'pebble': <gensim.models.keyedvectors.Vocab at 0x154486350d0>,
#  'backstage': <gensim.models.keyedvectors.Vocab at 0x15448635130>,
#  'charges': <gensim.models.keyedvectors.Vocab at 0x15448635190>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x154486351f0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x15448635250>,
#  'indoor': <gensim.models.keyedvectors.Vocab at 0x154486352b0>,
#  'situations': <gensim.models.keyedvectors.Vocab at 0x15448635310>,
#  'capture': <gensim.models.keyedvectors.Vocab at 0x15448635370>,
#  'requires': <gensim.models.keyedvectors.Vocab at 0x154486353d0>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x15448635430>,
#  'loudly': <gensim.models.keyedvectors.Vocab at 0x15448635490>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x154486354f0>,
#  'outdoor': <gensim.models.keyedvectors.Vocab at 0x15448635550>,
#  'opposite': <gensim.models.keyedvectors.Vocab at 0x154486355b0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x15448635610>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x15448635670>,
#  'pleasant': <gensim.models.keyedvectors.Vocab at 0x154486356d0>,
#  'irritatting': <gensim.models.keyedvectors.Vocab at 0x15448635730>,
#  'majorly': <gensim.models.keyedvectors.Vocab at 0x15448635790>,
#  'amd': <gensim.models.keyedvectors.Vocab at 0x154486357f0>,
#  'rarely': <gensim.models.keyedvectors.Vocab at 0x15448635850>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x154486358b0>,
#  'bother': <gensim.models.keyedvectors.Vocab at 0x15448635910>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x15448635970>,
#  'horn': <gensim.models.keyedvectors.Vocab at 0x154486359d0>,
#  'tips': <gensim.models.keyedvectors.Vocab at 0x15448635a30>,
#  'eventually': <gensim.models.keyedvectors.Vocab at 0x15448635a90>,
#  'settled': <gensim.models.keyedvectors.Vocab at 0x15448635af0>,
#  'mid': <gensim.models.keyedvectors.Vocab at 0x15448635b50>,
#  'default': <gensim.models.keyedvectors.Vocab at 0x15448635bb0>,
#  'regularly': <gensim.models.keyedvectors.Vocab at 0x15448635c10>,
#  'jogging': <gensim.models.keyedvectors.Vocab at 0x15448635c70>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x15448635cd0>,
#  'riding': <gensim.models.keyedvectors.Vocab at 0x15448635d30>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x15448635d90>,
#  'thay': <gensim.models.keyedvectors.Vocab at 0x15448635df0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x15448635e50>,
#  'loose': <gensim.models.keyedvectors.Vocab at 0x15448635eb0>,
#  'prolonged': <gensim.models.keyedvectors.Vocab at 0x15448635f10>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x15448635f70>,
#  'helmet': <gensim.models.keyedvectors.Vocab at 0x15448635fd0>,
#  'friendly': <gensim.models.keyedvectors.Vocab at 0x1544863a070>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1544863a0d0>,
#  'removing': <gensim.models.keyedvectors.Vocab at 0x1544863a130>,
#  'uncomfortable': <gensim.models.keyedvectors.Vocab at 0x1544863a190>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x1544863a1f0>,
#  'pinches': <gensim.models.keyedvectors.Vocab at 0x1544863a250>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x1544863a2b0>,
#  'plug': <gensim.models.keyedvectors.Vocab at 0x1544863a310>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x1544863a370>,
#  'washing': <gensim.models.keyedvectors.Vocab at 0x1544863a3d0>,
#  'bathroom': <gensim.models.keyedvectors.Vocab at 0x1544863a430>,
#  'seperated': <gensim.models.keyedvectors.Vocab at 0x1544863a490>,
#  'concrete': <gensim.models.keyedvectors.Vocab at 0x1544863a4f0>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x1544863a550>,
#  'noticable': <gensim.models.keyedvectors.Vocab at 0x1544863a5b0>,
#  'playing': <gensim.models.keyedvectors.Vocab at 0x1544863a610>,
#  'pubg': <gensim.models.keyedvectors.Vocab at 0x1544863a670>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x1544863a6d0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1544863a730>,
#  'slipped': <gensim.models.keyedvectors.Vocab at 0x1544863a790>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x1544863a7f0>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x1544863a850>,
#  'sounded': <gensim.models.keyedvectors.Vocab at 0x1544863a8b0>,
#  'summarise': <gensim.models.keyedvectors.Vocab at 0x1544863a910>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x1544863a970>,
#  'insert': <gensim.models.keyedvectors.Vocab at 0x1544863a9d0>,
#  'magnetically': <gensim.models.keyedvectors.Vocab at 0x1544863aa30>,
#  'exhausted': <gensim.models.keyedvectors.Vocab at 0x1544863aa90>,
#  'switchoff': <gensim.models.keyedvectors.Vocab at 0x1544863aaf0>,
#  'inserted': <gensim.models.keyedvectors.Vocab at 0x1544863ab50>,
#  'switched': <gensim.models.keyedvectors.Vocab at 0x1544863abb0>,
#  'manually': <gensim.models.keyedvectors.Vocab at 0x1544863ac10>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x1544863ac70>,
#  'recognise': <gensim.models.keyedvectors.Vocab at 0x1544863acd0>,
#  'hrs': <gensim.models.keyedvectors.Vocab at 0x1544863ad30>,
#  'upto': <gensim.models.keyedvectors.Vocab at 0x1544863ad90>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x1544863adf0>,
#  'messy': <gensim.models.keyedvectors.Vocab at 0x1544863ae50>,
#  'usage': <gensim.models.keyedvectors.Vocab at 0x1544863aeb0>,
#  'hassle': <gensim.models.keyedvectors.Vocab at 0x1544863af10>,
#  'switch': <gensim.models.keyedvectors.Vocab at 0x1544863af70>,
#  'transition': <gensim.models.keyedvectors.Vocab at 0x1544863afd0>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x15448640070>,
#  'hardly': <gensim.models.keyedvectors.Vocab at 0x154486400d0>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x15448640130>,
#  'equivalent': <gensim.models.keyedvectors.Vocab at 0x15448640190>,
#  'mrp': <gensim.models.keyedvectors.Vocab at 0x154486401f0>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x15448640250>,
#  'prity': <gensim.models.keyedvectors.Vocab at 0x154486402b0>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x15448640310>,
#  'counterparts': <gensim.models.keyedvectors.Vocab at 0x15448640370>,
#  'galaxy': <gensim.models.keyedvectors.Vocab at 0x154486403d0>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x15448640430>,
#  'glasses': <gensim.models.keyedvectors.Vocab at 0x15448640490>,
#  'scratches': <gensim.models.keyedvectors.Vocab at 0x154486404f0>,
#  'slips': <gensim.models.keyedvectors.Vocab at 0x15448640550>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x154486405b0>,
#  'robbery': <gensim.models.keyedvectors.Vocab at 0x15448640610>,
#  'jbl': <gensim.models.keyedvectors.Vocab at 0x15448640670>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x154486406d0>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x15448640730>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x15448640790>,
#  'batttery': <gensim.models.keyedvectors.Vocab at 0x154486407f0>,
#  'havent': <gensim.models.keyedvectors.Vocab at 0x15448640850>,
#  'checked': <gensim.models.keyedvectors.Vocab at 0x154486408b0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x15448640910>,
#  'banglore': <gensim.models.keyedvectors.Vocab at 0x15448640970>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x154486409d0>,
#  'companynoise': <gensim.models.keyedvectors.Vocab at 0x15448640a30>,
#  'goodfyi': <gensim.models.keyedvectors.Vocab at 0x15448640a90>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x15448640af0>,
#  'owner': <gensim.models.keyedvectors.Vocab at 0x15448640b50>,
#  'xdthe': <gensim.models.keyedvectors.Vocab at 0x15448640bb0>,
#  'cons': <gensim.models.keyedvectors.Vocab at 0x15448640c10>,
#  'tap': <gensim.models.keyedvectors.Vocab at 0x15448640c70>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x15448640cd0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x15448640d30>,
#  'prev': <gensim.models.keyedvectors.Vocab at 0x15448640d90>,
#  'earbud': <gensim.models.keyedvectors.Vocab at 0x15448640df0>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x15448640e50>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x15448640eb0>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x15448640f10>,
#  'goodps': <gensim.models.keyedvectors.Vocab at 0x15448640f70>,
#  'doesnt': <gensim.models.keyedvectors.Vocab at 0x15448640fd0>,
#  'snugly': <gensim.models.keyedvectors.Vocab at 0x15448645070>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x154486450d0>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x15448645130>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x15448645190>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x154486451f0>,
#  'initiated': <gensim.models.keyedvectors.Vocab at 0x15448645250>,
#  'returns': <gensim.models.keyedvectors.Vocab at 0x154486452b0>,
#  'rating': <gensim.models.keyedvectors.Vocab at 0x15448645310>,
#  'heavy': <gensim.models.keyedvectors.Vocab at 0x15448645370>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x154486453d0>,
#  'daypros': <gensim.models.keyedvectors.Vocab at 0x15448645430>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x15448645490>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x154486454f0>,
#  'mins': <gensim.models.keyedvectors.Vocab at 0x15448645550>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x154486455b0>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x15448645610>,
#  'devise': <gensim.models.keyedvectors.Vocab at 0x15448645670>,
#  'exceeded': <gensim.models.keyedvectors.Vocab at 0x154486456d0>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x15448645730>,
#  'reasons': <gensim.models.keyedvectors.Vocab at 0x15448645790>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x154486457f0>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x15448645850>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x154486458b0>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x15448645910>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x15448645970>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x154486459d0>,
#  'treadmill': <gensim.models.keyedvectors.Vocab at 0x15448645a30>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x15448645a90>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x15448645af0>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x15448645b50>,
#  'headsets': <gensim.models.keyedvectors.Vocab at 0x15448645bb0>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x15448645c10>,
#  'approximately': <gensim.models.keyedvectors.Vocab at 0x15448645c70>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x15448645cd0>,
#  'toss': <gensim.models.keyedvectors.Vocab at 0x15448645d30>,
#  'tells': <gensim.models.keyedvectors.Vocab at 0x15448645d90>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x15448645df0>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x15448645e50>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x15448645eb0>,
#  'suitable': <gensim.models.keyedvectors.Vocab at 0x15448645f10>,
#  'bubble': <gensim.models.keyedvectors.Vocab at 0x15448645f70>,
#  'inserting': <gensim.models.keyedvectors.Vocab at 0x15448645fd0>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x1544864b070>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x1544864b0d0>,
#  'paced': <gensim.models.keyedvectors.Vocab at 0x1544864b130>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x1544864b190>,
#  'games': <gensim.models.keyedvectors.Vocab at 0x1544864b1f0>,
#  'requested': <gensim.models.keyedvectors.Vocab at 0x1544864b250>,
#  'keeps': <gensim.models.keyedvectors.Vocab at 0x1544864b2b0>,
#  'disconnecting': <gensim.models.keyedvectors.Vocab at 0x1544864b310>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x1544864b370>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x1544864b3d0>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x1544864b430>,
#  'seemed': <gensim.models.keyedvectors.Vocab at 0x1544864b490>,
#  'helpless': <gensim.models.keyedvectors.Vocab at 0x1544864b4f0>,
#  'useless': <gensim.models.keyedvectors.Vocab at 0x1544864b550>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x1544864b5b0>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x1544864b610>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x1544864b670>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x1544864b6d0>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x1544864b730>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x1544864b790>,
#  'angles': <gensim.models.keyedvectors.Vocab at 0x1544864b7f0>,
#  'sync': <gensim.models.keyedvectors.Vocab at 0x1544864b850>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x1544864b8b0>,
#  'rough': <gensim.models.keyedvectors.Vocab at 0x1544864b910>,
#  'dayoverall': <gensim.models.keyedvectors.Vocab at 0x1544864b970>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x1544864b9d0>,
#  'tweaking': <gensim.models.keyedvectors.Vocab at 0x1544864ba30>,
#  'convenient': <gensim.models.keyedvectors.Vocab at 0x1544864ba90>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x1544864baf0>,
#  'grib': <gensim.models.keyedvectors.Vocab at 0x1544864bb50>,
#  'visually': <gensim.models.keyedvectors.Vocab at 0x1544864bbb0>,
#  'cancelation': <gensim.models.keyedvectors.Vocab at 0x1544864bc10>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x1544864bc70>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x1544864bcd0>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x1544864bd30>,
#  'testing': <gensim.models.keyedvectors.Vocab at 0x1544864bd90>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x1544864bdf0>,
#  'replaced': <gensim.models.keyedvectors.Vocab at 0x1544864be50>,
#  'hears': <gensim.models.keyedvectors.Vocab at 0x1544864beb0>,
#  'crackling': <gensim.models.keyedvectors.Vocab at 0x1544864bf10>,
#  'ordered': <gensim.models.keyedvectors.Vocab at 0x1544864bf70>,
#  'studying': <gensim.models.keyedvectors.Vocab at 0x1544864bfd0>,
#  ...}

# %%
model.wv.most_similar('good')
# Out:
# [('facebook', 0.8876641988754272),
#  ('removed', 0.762692928314209),
#  ('canceled', 0.7189207077026367),
#  ('email', 0.7174031734466553),
#  ('vanished', 0.6749992370605469),
#  ('deadline', 0.6575798988342285),
#  ('emphasize', 0.6532340049743652),
#  ('swaet', 0.6511964797973633),
#  ('neatly', 0.6492407917976379),
#  ('cant', 0.6344605684280396)]

# %%
model['great']
# Out:
# array([-0.01256191, -0.01444336,  0.00845158,  0.01779633, -0.01337242,
#         0.02316932,  0.0181849 ,  0.01128593,  0.02366651,  0.00219336,
#         0.01801266, -0.02080796,  0.02179068, -0.00940283, -0.02413159,
#        -0.02392056, -0.00292737,  0.02450658, -0.01236009,  0.02436279],
#       dtype=float32)

# %%
X = []
for i in review_df['combined']:
    lst = []
    n = 0
    for j in i:
        if j in list(model.wv.vocab):
            lst.append(model[j])
            n = n+1
    lst = np.array(lst)
    X.append([np.sum(lst[:,i])/n for i in range(20)])

# %%
X = np.array(X)

# %%
review_df.shape
# Out:
# (2755, 3)

# %%
np.shape(X)
# Out:
# (2755, 20)

# %%
y = review_df['star'].ravel()

X_train,X_valid,y_train,y_valid = train_test_split(X,y,test_size=0.3,random_state=17)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import numpy as np

def cross_val(model,X,y):
       
    f1_scr = []
    
    rfk = KFold(n_splits=3, random_state=None,shuffle = True)
    
    for train, test in rfk.split(X): ## you must do this on full dataset 
        print
        try:
            X_train = X.iloc[train]
            X_test = X.iloc[test]
            
        except:
            X_train = X[train,:]
            X_test = X[test,:]
                        
        y_train = y[train]
        y_test = y[test]
        
        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred,average = 'micro')
        f1_scr.append(f1)
    print('F1 Score',np.mean(f1_scr))
                    
    return model

# %%
from sklearn import metrics

def pred(model,X,y):
    y_pred = model.predict(X)
    f1 = f1_score(y, y_pred,average = 'micro')
    print(f1)
    print(metrics.confusion_matrix(y, y_pred))
    print(metrics.classification_report(y, y_pred))

# %%
from sklearn.linear_model import LogisticRegression

Log_Reg = LogisticRegression(random_state=0,solver='lbfgs',max_iter = 200)

Log_Reg = cross_val(Log_Reg,X_train,y_train)
pred(Log_Reg,X_valid,y_valid)
# Out:
# F1 Score 0.3848708594351827
# 0.4099153567110036
# [[  0   0 281]
#  [  0   0 207]
#  [  0   0 339]]
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       281
#            0       0.00      0.00      0.00       207
#            1       0.41      1.00      0.58       339
#
#     accuracy                           0.41       827
#    macro avg       0.14      0.33      0.19       827
# weighted avg       0.17      0.41      0.24       827
# C:\Users\sanja\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.tree import DecisionTreeClassifier

DCT_Classifier = DecisionTreeClassifier(criterion='entropy', random_state=1)

DCT_Classifier = cross_val(DCT_Classifier,X_train,y_train)
pred(DCT_Classifier,X_valid,y_valid)
# Out:
# F1 Score 0.4932551044962202
# 0.49455864570737607
# [[152  68  61]
#  [ 61  80  66]
#  [ 96  66 177]]
#               precision    recall  f1-score   support
#
#           -1       0.49      0.54      0.52       281
#            0       0.37      0.39      0.38       207
#            1       0.58      0.52      0.55       339
#
#     accuracy                           0.49       827
#    macro avg       0.48      0.48      0.48       827
# weighted avg       0.50      0.49      0.50       827

# %%
from sklearn.ensemble import RandomForestClassifier

RF_Classifier = cross_val(RandomForestClassifier(),X_train,y_train)
pred(RF_Classifier,X_valid,y_valid)
# Out:
# F1 Score 0.5669047123023083
# 0.599758162031439
# [[190  24  67]
#  [ 56  72  79]
#  [ 83  22 234]]
#               precision    recall  f1-score   support
#
#           -1       0.58      0.68      0.62       281
#            0       0.61      0.35      0.44       207
#            1       0.62      0.69      0.65       339
#
#     accuracy                           0.60       827
#    macro avg       0.60      0.57      0.57       827
# weighted avg       0.60      0.60      0.59       827

# %%
from xgboost import XGBClassifier

XGB_Classifier = cross_val(XGBClassifier(),X_train,y_train)
pred(XGB_Classifier,X_valid,y_valid)
# Out:
# F1 Score 0.5601727365073828
# 0.596130592503023
# [[168  33  80]
#  [ 42  93  72]
#  [ 57  50 232]]
#               precision    recall  f1-score   support
#
#           -1       0.63      0.60      0.61       281
#            0       0.53      0.45      0.49       207
#            1       0.60      0.68      0.64       339
#
#     accuracy                           0.60       827
#    macro avg       0.59      0.58      0.58       827
# weighted avg       0.59      0.60      0.59       827

# %%
from sklearn.svm import SVC

SVM_Classifier = cross_val(SVC(),X_train,y_train)
pred(SVM_Classifier,X_valid,y_valid)
# Out:
# F1 Score 0.5534270335217996
# 0.5465538089480049
# [[173  38  70]
#  [ 62  62  83]
#  [ 86  36 217]]
#               precision    recall  f1-score   support
#
#           -1       0.54      0.62      0.57       281
#            0       0.46      0.30      0.36       207
#            1       0.59      0.64      0.61       339
#
#     accuracy                           0.55       827
#    macro avg       0.53      0.52      0.52       827
# weighted avg       0.54      0.55      0.54       827

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

inertia_lst = []
for i in range(2,20):
    kmeans = KMeans(n_clusters=i, random_state=0).fit(X)
    inertia_lst.append(kmeans.inertia_)
    print(i,': ',silhouette_score(X, kmeans.labels_, metric='euclidean'))
    
plt.plot(range(2,20),inertia_lst)
plt.xlabel("Value of K") 
plt.ylabel("Sqaured Error (Cost)") 
plt.show()
# Out:
# 2 :  0.11317996222076643
# 3 :  0.106171031909608
# 4 :  0.0383704469359615
# 5 :  0.026108663208658327
# 6 :  0.019200843525477816
# 7 :  0.03077158040656559
# 8 :  0.010742317746080745
# 9 :  0.008558637561325345
# 10 :  0.012848375884480706
# 11 :  -0.0036250449363354137
# 12 :  0.0036099051873189143
# 13 :  0.0039330313224719094
# 14 :  0.005802096383836938
# 15 :  0.003465671956014624
# 16 :  -0.0017384624423205915
# 17 :  -0.003252051546694667
# 18 :  0.006433809501294921
# 19 :  -0.0019134065231489652
